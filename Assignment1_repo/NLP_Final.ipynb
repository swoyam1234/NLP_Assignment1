# %%
import re
import pandas as pd
import os
from nltk.tokenize import sent_tokenize  # Import the sentence tokenizer
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx

# %% [markdown]
# # **Preprocessing of sentences**

# %%
def remove_urls(sentences_list):
    cleaned_sentences = []
    url_pattern = re.compile(r'https?://\S+|www\.\S+')

    for sentence in sentences_list:
        # Tokenize each sentence into words and check if it contains a URL
        words = sentence.split()
        if not any(re.search(url_pattern, word) for word in words):
            cleaned_sentences.append(sentence)

    return cleaned_sentences

# %%
# Open the text file in read mode
file_path = "/content/drive/MyDrive/fns2020_dataset/training/annual_reports/92.txt"

sentences_lower = []

try:
    with open(file_path, 'r') as file:
        # Read the lines of the file into a list
        file_lines = file.readlines()

        # Remove leading and trailing whitespaces and store in a list
        sentences = [line.strip() for line in file_lines]


        sentences_lower = remove_urls(sentences)


        for i, sentence_lower in enumerate(sentences_lower):
            print(f" {i+1} : {sentence_lower}")

except FileNotFoundError:
    print(f"File {file_path} not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#  1 : UBC MEDIA GROUP PLC
#  2 : ANNUAL REPORT & ACCOUNTS 2005
#  3 : UBC MEDIA GROUP PLC  ANNUAL REPORT AND ACCOUNTS 2005
#  4 : UBC Media Group PLC
#  5 : 50 Lisson Street
#  6 : London NW1 5DF
#  7 : T: 020 7453 1600
#  8 : F: 020 7723 6132
#  9 : 01 Financial highlights
#  10 : 02 Chairman’s statement
#  11 : 03 Chief Executive’s statement
#  12 : 04 Commissioned programming
#  13 : 06 Syndicated programming
#  14 : 08 Radio stations
#  15 : 10 Radio services
#  16 : 12 Financial review
#  17 : 16 Board of directors
#  18 : 16 Directors and advisors
#  19 : 17 Report of the directors
#  20 : 19 Corporate governance statement
#  21 : 21 Statement of directors’ responsibilities
#  22 : 22 Remuneration report
#  23 : 23 Independent auditors’ report
#  24 : 24 Consolidated proﬁt and loss account
#  25 : 25 Consolidated balance sheet
#  26 : 26 Company balance sheet
#  27 : 27 Consolidated cash ﬂow statement
#  28 : 28 Notes to the ﬁnancial statements
#  29 : 46 Notice of AGM
#  30 : *Before goodwill and digital licences
#  31 : 01
#  32 : -519
#  33 : 04
#  34 : 13.29
#  35 : 03
#  36 : 10.32
#  37 : 02
#  38 : 9.19
#  39 : 01
#  40 : 6.18
#  41 : 05
#  42 : 15.96
#  43 : -210
#  44 : 02
#  45 : 73
#  46 : 03
#  47 : 405
#  48 : 04
#  49 : 1,075
#  50 : 05
#  51 : GROUP TURNOVER
#  52 : £ millions
#  53 : OPERATING PROFIT/(LOSS)*
#  54 : £ thousands UBC ENCOMPASSES A RANGE OF BUSINESSES SERVING THE GROWING DIGITAL
#  55 : RADIO SECTOR. UBC’S RADIO STATIONS INCLUDE THE NATIONAL DIGITAL
#  56 : STATIONS, CLASSIC GOLD DIGITAL AND ONEWORD RADIO. UBC IS ALSO A
#  57 : LEADING SUPPLIER OF RADIO SERVICES, INCLUDING SOFTWARE TO OPERATE
#  58 : DIGITAL RADIO DATA SERVICES. IN ADDITION, UBC RANKS AS THE LEADING
#  59 : INDEPENDENT SUPPLIER OF RADIO PROGRAMMES TO THE BBC AND THE
#  60 : COMMERCIAL RADIO INDUSTRY.
#  61 : TURNOVER BY DIVISION 2005
#  62 : 1
#  63 : TURNOVER BY DIVISION 2004
#  64 : COMMISSIONED
#  65 : PROGRAMMING
#  66 : £2.18m
#  67 : SYNDICATED
#  68 : PROGRAMMING
#  69 : £5.24 m
#  70 : RADIO
#  71 : SERVICES
#  72 : £1.18m
#  73 : CLASSIC
#  74 : GOLD DIGITAL
#  75 : £4.69m
#  76 : COMMISSIONED
#  77 : PROGRAMMING
#  78 : £2.93 m
#  79 : SYNDICATED
#  80 : PROGRAMMING
#  81 : £7.55 m
#  82 : RADIO
#  83 : SERVICES
#  84 : £1.08 m
#  85 : CLASSIC
#  86 : GOLD DIGITAL
#  87 : £4.41 m 2
#  88 : UBC MEDIA GROUP PLC
#  89 : CHAIRMAN’S STATEMENT
#  90 : John Hodson Chairman
#  91 : This is the ﬁrst opportunity I have had to write to the shareholders of
#  92 : UBC Media Group since my appointment as Chairman of the Company in
#  93 : February 2005.
#  94 : As the new Chairman I think it is helpful to reiterate the strategy that has
#  95 : guided the Group’s development since its ﬂotation in July 2000. This has been
#  96 : to maximise the returns from UBC’s traditional businesses as a means to ﬁnance
#  97 : the Group’s digital expansion, including the signiﬁcant programme of investment
#  98 : in its portfolio of digital assets.
#  99 : In keeping with UBC’s strategy, I am delighted to report another year of strong
#  100 : turnover growth for the Group. Turnover grew by 20% to £15.96 million (2004:
#  101 : £13.29 million). Operating Proﬁts for the Group increased to £1,075,000 (2004:
#  102 : £405,000) before goodwill of £704,000 and digital licences of £1.50 million.
#  103 : The growth in the past year reﬂects a combination of both organic growth and
#  104 : acquisitions, with positive contributions from all the Group’s main divisions.
#  105 : Full details of the performance of each of the Group’s divisions are contained in
#  106 : the Financial Review.
#  107 : I would like to take this opportunity to extend the thanks of the board to my
#  108 : predecessor, Michael Peacock, who performed the role of chairman of UBC with
#  109 : great skill since the Company was founded in 1989. Michael’s contribution to the
#  110 : business has been enormous, bringing to UBC all the experience gained from a
#  111 : long and distinguished career in the media industry. On behalf of my colleagues
#  112 : I would like to express my appreciation to Michael for all he has done to guide
#  113 : UBC to where it is today and to wish him a long and well deserved retirement.
#  114 : Following his decision to stand down as a director, I would also like to thank
#  115 : Keith Harris on behalf of the rest of the Board for his long standing contribution
#  116 : to the Company, and most recently for his services as a director of UBC.
#  117 : The commercial and creative successes of the past year could not have been
#  118 : achieved without the enthusiasm and commitment of the whole team at UBC.
#  119 : The Company has a highly talented workforce and it is their consistent and
#  120 : focused efforts that have enabled us to deliver a further year of strong growth.
#  121 : UBC is founded on a culture of innovation and creativity and the strong
#  122 : performance of the past year is evidence of the robust and complementary mix of
#  123 : businesses within the Group. The Company is led by an established management
#  124 : team that is young and energetic, and with ambitions to grow the business
#  125 : substantially over the next few years. I believe that with a continuing favourable
#  126 : environment the prospects for the Company in the current year are good.
#  127 :
#  128 : John Hodson
#  129 : Chairman I am pleased to be able to report a further year of strong growth for UBC
#  130 : Media Group, delivering on our past commitment to shareholders and
#  131 : putting in place a robust foundation for the next stage in the development
#  132 : of your company.
#  133 : Digital radio is now a success story, with the UK leading the world. Key skills for
#  134 : exploiting the digital marketplace are the supply of content, control of spectrum
#  135 : and software development. UBC is well placed in each of these areas, with skills
#  136 : and experience, as is evident from a number of developments during the last
#  137 : year, both in the UK and overseas.
#  138 : The high growth digital radio environment that we anticipated and around which
#  139 : we have built UBC is now upon us. DAB is proving to be one of the fastest ever
#  140 : new technologies to reach mass market status and the industry’s forecasts
#  141 : for take-up this year are currently being revised upwards. UBC has sought to
#  142 : create the right business mix for an environment that we believe will operate on
#  143 : different economic models from that of the traditional analogue radio world.
#  144 : The creation of strong brands is of growing importance in what is an increasingly
#  145 : competitive marketplace. In this respect, our partnership with Channel 4
#  146 : Television in our national digital radio station, Oneword Radio, is of particular
#  147 : signiﬁcance, and also demonstrates the increasing value of ownership of digital
#  148 : radio licences.
#  149 : As we predicted, networking and the ability to generate revenues by providing
#  150 : programming to stations owned by others is becoming a key part of the digital
#  151 : radio economy. It is in this area that we have seen particularly strong growth in
#  152 : the past year. Our syndicated programmes now reach 34% of the UK population
#  153 : every day and revenues grew 44.1% in the year. The acquisition of the leading
#  154 : regional independent production company, Smooth Operations, has made an
#  155 : important contribution to a 34.4% growth in revenues from commissioned
#  156 : programming. We continue to be one of the leading suppliers of programmes
#  157 : to the BBC and the value of this position is ampliﬁed by the BBC’s intention to
#  158 : double the programming it commissions from independent production companies.
#  159 : Whilst we welcome a step that will beneﬁt our production businesses, it will
#  160 : still leave radio outsourcing signiﬁcantly behind that of television. We see no
#  161 : CHIEF EXECUTIVE’S STATEMENT
#  162 : ANNUAL REPORT AND ACCOUNTS 2005
#  163 : 3
#  164 : justiﬁcation for this, and are lobbying government as part of the current Charter
#  165 : Review process to encourage greater movement from the BBC.
#  166 : Digital radio offers the opportunity to bring real vision to the radio industry. UBC
#  167 : Media Group’s strategy has been to anticipate how digital radio will develop,
#  168 : and position the Company to beneﬁt from new opportunities as they emerge.
#  169 : We believe the ability to transmit data will be one of the key drivers of the
#  170 : next stage in the development of DAB digital radio. We already have a 40% UK
#  171 : market share for the provision of software to drive the existing text services that
#  172 : accompany digital radio broadcasts. This, however, is only the beginning: devices
#  173 : are now being launched which allow full Electronic Programme Guides (EPG) and
#  174 : facilitate sophisticated services using digital radio’s data capacity.
#  175 : UBC has the only commercially available EPG software in the UK and has already
#  176 : licensed this to major UK broadcasters, including GCap Media and the recently
#  177 : announced BT Livetime datacasting venture. A major part of our investment in
#  178 : 2006 will focus on exploring ways to exploit the data capacity that is owned by
#  179 : UBC and, in particular, on the launch of innovative services that allow music to
#  180 : be downloaded over digital radio. We expect to launch such a service in the
#  181 : next calendar year.
#  182 : UBC’s aim continues to be to grow the business both organically and by
#  183 : acquisition. We remain committed to investing in the development of
#  184 : our portfolio of digital assets and to maintaining our position at the
#  185 : forefront of innovation and technical achievement. Since the start of
#  186 : the new ﬁnancial year, as has been widely reported elsewhere, the
#  187 : radio advertising market has shown signs of softening. However,
#  188 : we continue to see advertising revenues higher than at this
#  189 : time last year. The Group continues to perform in line with
#  190 : expectations and we believe the prospects for the year
#  191 : ahead are positive.
#  192 : Simon Cole
#  193 : Chief Executive
#  194 : Simon Cole Chief Executive 4
#  195 : UBC IS THE LARGEST INDEPENDENT RADIO PRODUCTION
#  196 : COMPANY IN THE UK. IN 2005 UBC’S PRODUCTION BUSINESSES,
#  197 : UNIQUE AND SMOOTH OPERATIONS, PRODUCED OVER 600 HOURS
#  198 : OF COMMISSIONED PROGRAMMING FOR THE BBC.
#  199 : IN AUGUST 2004 UBC ACQUIRED SMOOTH OPERATIONS, THE UK’S LEADING
#  200 : REGIONAL INDEPENDENT PRODUCTION COMPANY. THE INTEGRATION OF
#  201 : SMOOTH OPERATIONS HAS PROGRESSED WELL AND IN THE LAST YEAR THE
#  202 : GROUP HAS SEEN STRONG GROWTH IN REVENUES FROM COMMISSIONED
#  203 : PROGRAMMING TO THE BBC. UBC IS WELL POSITIONED TO TAKE ADVANTAGE OF
#  204 : THE BBC’S PLANS TO INCREASE BOTH ITS REGIONAL OUTPUT AND THE AMOUNT
#  205 : OF INDEPENDENTLY PRODUCED PROGRAMMING IT BROADCASTS.  UBC RANKS AS ONE OF THE LARGEST SUPPLIERS OF SYNDICATED
#  206 : PROGRAMMES TO COMMERCIAL RADIO – SUPPLYING BOTH THE
#  207 : NETWORK DRIVE AND ENTERTAINMENT NEWS SERVICES.
#  208 : IN 2005 UBC’S SYNDICATED AIRTIME SALES BUSINESS DELIVERED
#  209 : STRONG GROWTH AS A RESULT OF COMBINING UBC’S AND EMAP’S
#  210 : SYNDICATED RADIO AIRTIME SALES NETWORKS AND THE LAUNCH OF A
#  211 : CONSOLIDATED TRAFFIC AND TRAVEL SERVICE. THE MARKET FOR UBC’S
#  212 : SYNDICATED RADIO PROGRAMMING CONTINUES TO BE STRONG AS THE
#  213 : COMMERCIAL RADIO SECTOR INCREASINGLY RECOGNISES ITS NEED TO
#  214 : INVEST IN HIGH–QUALITY PROGRAMMING.
#  215 : 6  CLASSIC GOLD DIGITAL AND ONEWORD RADIO ARE
#  216 : PRIME ASSETS IN DIGITAL RADIO.
#  217 : CLASSIC GOLD DIGITAL RANKS AS ONE OF THE TOP ‘GOLD’
#  218 : FORMATS IN THE UK, AND IS BROADCAST ON BOTH ANALOGUE
#  219 : AND DIGITAL PLATFORMS, REACHING A POTENTIAL UK ADULT
#  220 : AUDIENCE OF 29 MILLION. ONEWORD RADIO OWNS THE UK’S
#  221 : ONLY COMMERCIAL DIGITAL SPOKEN–WORD LICENCE. WE
#  222 : BELIEVE THAT CHANNEL 4’S TIE-UP WITH UBC IN THE JOINT
#  223 : OWNERSHIP OF ONEWORD RADIO IS A KEY DEVELOPMENT IN
#  224 : THE GROWTH OF DIGITAL RADIO IN THE UK.
#  225 : 8  THE LAUNCH OF A NEW GENERATION OF DIGITAL RADIO
#  226 : SERVICES WILL FUNDAMENTALLY CHANGE THE DEVELOPMENT
#  227 : OF DIGITAL RADIO.
#  228 : UBC EXPECTS THE NEXT FEW YEARS WILL SEE THE LAUNCH OF A NEW
#  229 : GENERATION OF RADIO RECEIVERS CAPABLE OF DELIVERING SERVICES
#  230 : NEVER BEFORE AVAILABLE ON RADIO. THE LAUNCH IN 2005 OF THE FIRST
#  231 : EPG–ENABLED DEVICES WILL BE FOLLOWED BY THE LAUNCH OF NEW
#  232 : RADIO SERVICES, SUCH AS MUSIC DOWNLOADING. UBC’S OWNERSHIP
#  233 : OF DATA SPECTRUM AND EXPERIENCE IN RADIO SOFTWARE SERVICES
#  234 : PLACES THE GROUP AT THE FOREFRONT OF THIS MARKET.
#  235 : 10  12
#  236 : UBC MEDIA GROUP PLC
#  237 : Financial highlights
#  238 : The main ﬁnancial highlights of UBC Media Group for the year to
#  239 : 31 March 2005 are as follows:
#  240 : – Turnover increased 20% to £15.96 million (2004: £13.29 million).
#  241 : –  Operating Proﬁt for the year before goodwill and digital licences
#  242 : totalled £1,075,000 (2004: £405,000), while operating loss after
#  243 : goodwill and digital licences were –£1,093,000 (2004: –£1,016,000).
#  244 : –  Operating Proﬁt, excluding goodwill and investment in Oneword Radio
#  245 : as a subsidiary was £161,000 (2004: –£675,000). Investment during the
#  246 : year in Oneword Radio as a subsidiary totalled £589,000 (2004:nil.)
#  247 : –  Digital licences in the year totalled £1.50 million (2004: £1.08 million),
#  248 : which includes the Company’s investment in Oneword Radio’s digital
#  249 : licence while it was a subsidiary company.
#  250 : –  At 31 March 2005 UBC had cash in the bank of £3.50 million (2004:
#  251 : £4.32 million)
#  252 : Financial performance by division
#  253 : PRODUCTION
#  254 : UBC’s Production Division encompasses both the Group’s commissioned
#  255 : radio programming for the BBC and syndicated programming for the
#  256 : commercial radio industry.
#  257 : Commissioned Programming
#  258 : 2005 2004
#  259 : £m £m % Change
#  260 : Turnover 2.93 2.18 +34.4
#  261 :
#  262 : UBC’s commissioned programming business for the BBC comprises the
#  263 : Group’s historic production business, Unique, and the leading regional
#  264 : independent production company, Smooth Operations, which UBC
#  265 : acquired in August 2004.
#  266 : The integration of Smooth Operations, which operates from ofﬁces in
#  267 : Manchester and Cambridge, has progressed well and Unique continues
#  268 : to recover from the expiry of one of its long-standing commissions
#  269 : at the start of the ﬁnancial year. Turnover for the year was ahead by
#  270 : 34.4% at £2.93 million (2004: £2.18 million), and includes an 8 months’
#  271 : contribution from Smooth Operations of turnover of £1.14 million.
#  272 : Unique and Smooth Operations produce a wide range of programmes
#  273 : for broadcast across the BBC’s network of national analogue and digital
#  274 : stations. Unique and Smooth Operations produce more than 600 hours of
#  275 : programming for the BBC per year across a number of genres, with much
#  276 : of their output as long-term commissions for some of the BBC’s ﬂagship
#  277 : radio programmes. As an indication of the creative skills within the
#  278 : Group, this year UBC received a record number of Sony Radio Academy
#  279 : nominations for its programmes, including winning two prestigious Sony
#  280 : Radio Academy Gold Awards.
#  281 : The acquisition of Smooth Operations, which specialises in the Folk
#  282 : and Country music genres, was an important strategic move by UBC in
#  283 : a sector that it knows well and where prospects for signiﬁcant organic
#  284 : growth have historically been limited. The strategic importance of
#  285 : the acquisition of Smooth Operations was underlined by the BBC’s
#  286 : announcement in December 2004 of its intention to invest signiﬁcantly
#  287 : in production resources in Manchester. In addition, UBC believes both
#  288 : Unique and Smooth Operations are well positioned to beneﬁt from
#  289 : the BBC’s announcement during the year that it intends to double
#  290 : the number of hours allocated to independent radio production by its
#  291 : national radio networks.
#  292 : FINANCIAL REVIEW
#  293 : Jennifer Donald Finance Director 13
#  294 : ANNUAL REPORT AND ACCOUNTS 2005
#  295 : Syndicated Programming
#  296 : 2005 2004
#  297 : £m £m % Change
#  298 : Turnover 7.55 5.24 +44.1
#  299 :
#  300 : UBC operates two networks of syndicated programmes, Entertainment
#  301 : News and the Network Drive trafﬁc & travel service, both of which UBC
#  302 : supplies free of charge to radio stations across the UK while retaining
#  303 : airtime within each bulletin which is then available to UBC to sell to
#  304 : national advertisers.
#  305 : Revenues from UBC’s airtime sales business were up 44.1% in the year
#  306 : to £7.55 million (2004: £5.24 million). The strong performance by the
#  307 : airtime sales business followed a doubling of revenues from syndicated
#  308 : programming in the year to 31 March 2004.
#  309 : The signiﬁcant increase in airtime sales revenues in the year reﬂects
#  310 : in particular the substantial growth of the trafﬁc & travel news service
#  311 : in the ﬁrst-half of the ﬁnancial year. In July 2004 Emap and UBC
#  312 : consolidated their competing trafﬁc & travel services into a combined
#  313 : package encompassing over 174 commercial radio stations to be sold
#  314 : by UBC. The network was relaunched in August as one of the largest
#  315 : syndicated packages in the UK, delivering a weekly reach of over 15.1
#  316 : million adults and over 141 million adult impacts. The consolidation of
#  317 : competing airtime packages was followed in September 2004 by UBC’s
#  318 : appointment of Trafﬁclink as sole supplier of trafﬁc and travel data to
#  319 : the Network Drive service.
#  320 : We believe that in the future syndicated programming will become an
#  321 : increasingly important feature of the commercial radio market. The
#  322 : growth in digital radio will result in there being more radio stations in
#  323 : each market, and in response to market fragmentation advertisers will
#  324 : seek advertising properties that deliver national reach. One of the main
#  325 : challenges facing radio groups in this changed environment will be how
#  326 : to provide cost effective, high-quality programming, and in particular
#  327 : programming which can compete against the BBC’s output. UBC believes
#  328 : that networked programming is likely to form an important part of the
#  329 : solution to these competitive challenges.
#  330 : As a consequence, UBC is continuing to explore ways in which to grow
#  331 : its syndicated programming business. In September 2004 UBC acquired
#  332 : a 12.5% shareholding in Popworld Limited, which owns and controls
#  333 : Channel 4’s ﬂagship music-based programme of the same name and
#  334 : which is also broadcast on MTV. As part of its investment UBC became
#  335 : Popworld’s radio partner with exclusive responsibility for exploitation
#  336 : of the Popworld brand through networked programming to commercial
#  337 : radio stations.
#  338 : RADIO STATIONS
#  339 : UBC’s two main radio stations are Classic Gold Digital, which broadcasts
#  340 : a Classic Hits format on a network of analogue and digital platforms
#  341 : across the UK, and the national, digital spoken-word radio station,
#  342 : Oneword Radio.
#  343 : Classic Gold Digital
#  344 : 2005 2004
#  345 : £m £m % Change
#  346 : Turnover 4.41 4.69 –6.0
#  347 :
#  348 : Classic Gold Digital Limited performed in line with expectations in the
#  349 : year to 31 March 2005, with revenues down 6% on the previous year,
#  350 : at £4.41 million (2004: £4.69 million).
#  351 : Classic Gold Digital’s revenues are directly based upon the network’s
#  352 : audience as measured by RAJAR, in the form of an audience fee that
#  353 : GCap Media pays to Classic Gold Digital in return for it selling airtime
#  354 : on the network. The RAJAR results during the year for Classic Gold
#  355 : Digital have shown a modest decline in audiences. Overall, the long-
#  356 : term decline in audiences common to radio services broadcast on AM
#  357 : frequencies has been partially compensated for by growth in digital
#  358 : audiences. As part of its long-term strategy to maintain audiences,
#  359 : Classic Gold Digital has continued to invest throughout the year in high
#  360 : quality programming output and marketing.
#  361 : The RAJAR report for the ﬁnal quarter of the ﬁnancial year ended
#  362 : 31 March 2005 shows that 30% of Classic Gold Digital’s listeners are
#  363 : listening to the station on digital, up from 25% in the preceding quarter.
#  364 : In addition, the number of listeners in areas where Classic Gold Digital
#  365 : is only available digitally has increased by 7%. With the increasing
#  366 : growth of digital listening, one of the key challenges facing the radio
#  367 : industry in the forthcoming year will be educating advertisers to place
#  368 : equal value on both analogue and digital listening.
#  369 : GCap Media holds an option that it may exercise from October 2005
#  370 : to increase its shareholding in Classic Gold Digital from its current
#  371 : 20% to 75%. The price GCap Media is required to pay UBC to increase
#  372 : its shareholding in Classic Gold Digital is based on a formula agreed
#  373 : in October 2000. UBC has currently received no indication from GCap
#  374 : Media of any plans to increase its shareholding in Classic Gold Digital.
#  375 : Oneword Radio
#  376 : The past year was a transitional period for Oneword Radio. In June 2004
#  377 : UBC increased its shareholding in Oneword Radio to 100% as a means
#  378 : of ensuring the long-term future of the station. As a consequence of
#  379 : taking full control of Oneword Radio, the results of UBC for the year to
#  380 : 31 March 2005 include a period of 9 months when Oneword Radio was
#  381 : treated as a wholly owned subsidiary of the Company. 14
#  382 : UBC MEDIA GROUP PLC
#  383 : As a result of a restructuring programme that took place at the same
#  384 : time that UBC acquired full control of Oneword Radio, the cost of
#  385 : operating Oneword Radio was closely controlled throughout the year.
#  386 : At the same time it has shown steady audience growth year-on-year,
#  387 : with audiences in the ﬁrst quarter of 2005 up 60% on the same period
#  388 : in 2004.
#  389 : It was UBC’s intention when it acquired full control of Oneword Radio
#  390 : to identify a strategic partner for the station with a shared vision of
#  391 : the prospects for digital radio in the UK. Following the ﬁnancial year-
#  392 : end, in April 2005 UBC reached agreement with Channel 4 Television
#  393 : for Channel 4 to acquire a 51% interest in Oneword Radio for a cash
#  394 : consideration of £1 million. It is our expectation that the cost of UBC’s
#  395 : investment in Oneword Radio will reduce in the current year following
#  396 : the sale of a shareholding in the station. UBC and Channel 4 are
#  397 : currently working on plans jointly to develop Oneword Radio; building
#  398 : on what we believe is a valuable digital asset that has signiﬁcant
#  399 : growth prospects.
#  400 : RADIO SERVICES
#  401 : UBC’s Radio Services division comprises the Group’s digital software
#  402 : development and facilities businesses.
#  403 : 2005 2004
#  404 : £m £m % Change
#  405 : Turnover 1.08 1.18 –8.47
#  406 :
#  407 : Turnover from Radio Services in the year was £1.08 million (2004: £1.18
#  408 : million), representing a fall of 8.47% on the previous year. The decline in
#  409 : turnover experienced by Radio Services reﬂects a further fall in turnover
#  410 : from the Group’s facilities and studios business as we continue to focus
#  411 : on higher margin business in this area. This was partly compensated for
#  412 : in the period by a 45% increase in turnover from software sales to the
#  413 : radio industry.
#  414 : Unique Interactive
#  415 : Unique Interactive continues to beneﬁt from the increasing investment by
#  416 : both UK and overseas radio broadcasters in their digital services. Unique
#  417 : Interactive’s development focus continues to be on the Group’s two main
#  418 : software products: the ‘ManDLS’ software, which is used to manage the
#  419 : scrolling text (Dynamic Label Segment) of a digital radio service; and the
#  420 : development of software to operate electronic programme guide (EPG)
#  421 : services which form part of the interactive capabilities of an emerging
#  422 : new generation of EPG-enabled digital devices.
#  423 : Unique Interactive’s EPG software continues to be the only commercially
#  424 : available radio EPG, and it was a key element in the launch of the ﬁrst
#  425 : EPG-enabled receivers in early 2005. UBC has for a long time believed
#  426 : that the launch of EPG-capable digital radios will signiﬁcantly change
#  427 : the way that broadcasters and listeners utilise digital radio, and that
#  428 : in the future digital radios will incorporate features as standard which
#  429 : will transform the capabilities of the medium, such as rewind, record
#  430 : and download. These will enable additional access to a signiﬁcantly
#  431 : enhanced range of information services, and will change the current
#  432 : common perception that digital radio is only about greater listener
#  433 : choice and better sound quality.
#  434 : Unique Interactive is a market leader in software development for digital
#  435 : radio services as a result of its early investment in this area and it is
#  436 : currently developing an increasing international proﬁle in the delivery of
#  437 : software solutions to the industry. Unique Interactive is currently working
#  438 : with a number of leading broadcasting and technology companies in
#  439 : the UK and overseas and we believe the next 12 months will see major
#  440 : developments that will reinforce UBC’s prominence in this area.
#  441 : Since the year-end UBC has announced its intention to invest
#  442 : approximately £400,000 in the ﬁrst half of the current ﬁnancial year on
#  443 : creating an innovative service which will allow music to be downloaded
#  444 : over digital radio. The music downloading service will utilise data
#  445 : capacity on a number of digital radio multiplexes that are owned by UBC.
#  446 : The Company has begun negotiation with partners in the music and radio
#  447 : industries with whom it will work on bringing this service to market. The
#  448 : Company’s plans in this area are still at an early stage of development,
#  449 : but it is intended that investors will be updated on progress at the time
#  450 : of the Company’s interim announcement in November 2005.
#  451 : Unique Facilities
#  452 : Unique Facilities delivered a satisfactory performance in the year to
#  453 : 31 March 2005 and continued for much of the year to grow yields
#  454 : on the back of good occupancy rates. Despite operating in a highly
#  455 : competitive market, UBC’s facilities have operated at full capacity for
#  456 : extended periods during the year. In addition, Unique Facilities has
#  457 : sought to extend its audio creative services, with the successful launch
#  458 : of a number of new products, including the composition of theme and
#  459 : incidental music for television programmes and bespoke music jingles.
#  460 : Acquisitions & disposals
#  461 : UBC increased its shareholding in Oneword Radio Limited to 100% on
#  462 : 30 June 2004 when it acquired the 50% shareholding of USI Holdings
#  463 : Limited for £694,000. In consideration, UBC issued approximately 2.44
#  464 : million new UBC ordinary shares.
#  465 : In July 2004 UBC increased its shareholding in Digital News Network,
#  466 : which broadcasts a regional data service on ﬁve MXR multiplexes, from
#  467 : 21.95% to 28.05% at a cost of approximately £32,000.
#  468 : In August 2004 UBC acquired the business of Smooth Operations,
#  469 : a leading UK independent regional radio producer. The acquisition
#  470 : consideration comprised an initial payment of £1.8 million, with a further
#  471 : maximum payment of £1.9 million depending upon the proﬁt growth in
#  472 : each of the two years following the acquisition. A cash payment of £1.2
#  473 : million and the issue of approximately 2.45 million new UBC ordinary
#  474 : shares satisﬁed the initial acquisition consideration, plus costs incurred
#  475 : in connection with the acquisition of £79,000. Any further consideration
#  476 : will be payable as to 60% in cash and 40% by the issue of new UBC
#  477 : FINANCIAL REVIEW 15
#  478 : ANNUAL REPORT AND ACCOUNTS 2005
#  479 : ordinary shares. The ﬁrst part of the deferred consideration will become
#  480 : payable in the second-half of the ﬁnancial year to 31 March 2006, and
#  481 : this element is capped at £665,000 and is payable in a mixture of cash
#  482 : and new UBC ordinary shares.
#  483 : In September 2004 UBC announced the acquisition of a 12.5%
#  484 : shareholding in Popworld Limited, which owns and controls the
#  485 : music programme, Popworld, broadcast on Channel 4 and MTV. The
#  486 : consideration of £250,000 was settled in cash. UBC had an option to
#  487 : increase its shareholding in Popworld further to 25% at any time up to
#  488 : the end of December 2004 for a further consideration of £250,000.
#  489 : The option was not exercised.
#  490 : In April 2005 UBC sold a 51% interest in Oneword Radio Limited to
#  491 : Channel 4 Television Corporation for a cash consideration of £1 million.
#  492 : Channel 4’s investment in Oneword Radio represents the ﬁrst partnership
#  493 : of a national television and commercial radio station and potentially
#  494 : mirrors the BBC’s ownership of a cross-media brand. UBC and Channel
#  495 : 4 are currently working together on ways to develop Oneword Radio,
#  496 : including cross-promoting Oneword Radio and utilising the Channel 4
#  497 : brand name.
#  498 : Fund Raising and use of proceeds
#  499 : In July 2004 UBC placed approximately 7.8 million new ordinary shares
#  500 : with institutional investors, raising an additional £1.8 million (before
#  501 : expenses) for the Company. The net proceeds of the placing were
#  502 : used to satisfy the initial cash consideration and related costs of the
#  503 : acquisition of Smooth Operations and a 12.5% shareholding in Popworld
#  504 : Limited. The balance of the proceeds will be used to fund the balance of
#  505 : any deferred cash consideration of the acquisition.
#  506 : Investment in digital radio
#  507 : During the year to 31 March 2005 UBC invested the following amounts
#  508 : in digital licences:
#  509 : –   Investment in subsidiary companies of £1.50 million (2004: £1.52
#  510 : million), of which £963,000 (2004: £947,000) relates to carriage of
#  511 : Classic Gold Digital on digital multiplexes covering Northern England
#  512 : and Greater London and other areas which broaden Classic Gold
#  513 : Digital’s coverage; £394,000 (2004: £nil.) on Oneword Radio; and
#  514 : £144,000 (2004: £133,000) to data licence fees for broadcasting
#  515 : regional data services on ﬁve MXR digital multiplexes.
#  516 : –  Joint Venture Investment of £60,000 (2004: £436,000) in
#  517 : Oneword Radio.
#  518 : Cash Flow
#  519 : During the year UBC had a cash inﬂow from operating activities after
#  520 : digital licences and before investment in Oneword Radio and working
#  521 : capital of £96,000 (2004: –£520,000).
#  522 : Cash
#  523 : At 31 March 2005 UBC had cash in the bank of £3.50 million
#  524 : (2004: £4.32 million).
#  525 : International Financial Reporting Standards (IFRS)
#  526 : As a result of a review of its accounting policies it is UBC Media Group’s
#  527 : intention to comply with IFRS standards for the year ended 31 March
#  528 : 2008 in accordance with regulations applicable to AIM listed companies.
#  529 : Payment of Dividend
#  530 : The Board is not recommending the payment of a dividend.
#  531 : Jennifer Donald
#  532 : Finance Director 16
#  533 : UBC MEDIA GROUP PLC
#  534 : BOARD OF DIRECTORS
#  535 : John Hodson (58) Non-Executive Chairman
#  536 : John Hodson was appointed to the Board as Non-Executive Chairman of the
#  537 : Company in February 2005. Prior to December 2004 John was Chief Executive
#  538 : of Singer & Friedlander Group. Other non-executive directorships held by John
#  539 : include Domino’s Pizza UK & IRL plc and Prestbury Group. John is Chairman of
#  540 : the Nominations Committee and a member of the Remuneration Committee.
#  541 : Simon Cole (47) Chief Executive
#  542 : Simon Cole founded Unique Broadcasting in 1989 in partnership with Tim
#  543 : Blackmore, having pioneered the market for national sponsored programmes
#  544 : whilst at Piccadilly Radio, where he was Head of Programmes. Simon has
#  545 : been awarded a fellowship of the Radio Academy. Simon is a member of
#  546 : the Nominations Committee.
#  547 : Jennifer Donald (50) Finance Director
#  548 : Jennifer Donald qualiﬁed as a chartered accountant with KPMG and has
#  549 : held directorships in a number of private and publicly owned companies.
#  550 : Prior to joining the Board in December 2000, Jennifer was Finance Director
#  551 : of McCarthy Corporation plc. Jennifer is a member of the Nominations
#  552 : Committee.
#  553 : Matthew Honey (39) Managing Director, Unique Interactive
#  554 : Matthew Honey is Managing Director of Unique Interactive, with
#  555 : responsibility for the Group’s Radio Services activities. Matthew joined
#  556 : Unique Broadcasting in 1992 and prior to his appointment as Managing
#  557 : Director of Unique Interactive in December 2000 served as Finance Director
#  558 : of the Group. Matthew qualiﬁed as a chartered accountant with Coopers
#  559 : & Lybrand.
#  560 : John Quinn (48) Commercial Director
#  561 : John Quinn has overall responsibility for the Group’s commercial airtimes sales.
#  562 : John joined Unique Broadcasting in 1996. He was formerly Sales Controller for
#  563 : Virgin Radio and Atlantic 252 and launch Sales Director of Kiss FM.
#  564 : Tim Blackmore MBE (60) Non-Executive Director and Group
#  565 : Editorial Director
#  566 : Tim Blackmore founded Unique Broadcasting in 1989 with Simon Cole, after
#  567 : a career in radio production with BBC Radio One and Capital Radio. In April
#  568 : 2004 Tim was appointed as a Non-Executive Director, having stepped down
#  569 : from day-to-day executive responsibilities. He continues to act as Group
#  570 : Editorial Director for UBC Media Group and as Chairman of Classic Gold
#  571 : Digital and Smooth Operations and as a director of Oneword Radio. Tim
#  572 : served as the ﬁrst Director of the Radio Academy and was awarded an
#  573 : MBE for services to independent radio production. Tim has also been awarded
#  574 : a fellowship of the Radio Academy and is Chairman of the Sony Radio
#  575 : Academy Awards.
#  576 : Noel Edmonds (56) Non-Executive Director
#  577 : During a 30-year career with the BBC, Noel Edmonds presented some of the
#  578 : Corporation’s highest rating entertainment shows. In 1986 Noel established
#  579 : the Unique Group of companies, a privately owned media and communications
#  580 : group engaged in television and event production, video communication and
#  581 : talent management.
#  582 : Kelvin Harrison (50) Non-Executive Director
#  583 : Kelvin Harrison is a chartered engineer with signiﬁcant experience of the
#  584 : software, electronics and communications sectors in various positions,
#  585 : including chief executive of public and private companies. Kelvin is also Chief
#  586 : Executive of Maxima Holdings plc. Kelvin is Chairman of the Remuneration
#  587 : Committee and a member of the Audit Committee.
#  588 : Paul Pascoe (44) Non-Executive Director
#  589 : Paul Pascoe is Chief Executive Ofﬁcer of the Unique Group of companies,
#  590 : which are engaged in television and event production, video communication
#  591 : and talent management. Paul serves as a Non-Executive Director of UBC
#  592 : Media Group and is Chairman of the Audit Committee and a member of the
#  593 : Remuneration Committee.
#  594 : Michael Peacock OBE (75) Non-Executive Director
#  595 : Michael Peacock stood down as Non-Executive Chairman of UBC Media
#  596 : Group in February 2005 after 16 years of service, and is due to retire as a
#  597 : Non-Executive Director of UBC Media Group at the Company’s AGM in July
#  598 : 2005. Michael is a former Controller of BBC1. Other senior management
#  599 : positions held by him include Managing Director of London Weekend
#  600 : Television and Executive Vice President of Warner Bros TV. Michael is also a
#  601 : Governor of the London School of Economics and in June 2005 was awarded
#  602 : an OBE in the Queen’s Birthday Honours for services to higher education.
#  603 : In the year to 31 March 2005 Michael was a member of the Audit and
#  604 : Remuneration committees.
#  605 : Professor Roger Silverstone (60) Non-Executive Director
#  606 : Roger Silverstone is Professor of Media and Communications at the London
#  607 : School of Economics, having previously worked in television research and
#  608 : production for London Weekend Television, Associated Television and the
#  609 : BBC. Roger is a member of the Audit and Remuneration committees.
#  610 : Executive directors
#  611 : Simon A Cole
#  612 : Jennifer H Donald
#  613 : Matthew A Honey
#  614 : John P Quinn
#  615 : Non-executive directors
#  616 : John Hodson
#  617 : Timothy J. Blackmore MBE
#  618 : Noel E. Edmonds
#  619 : Keith R. Harris *
#  620 : Kelvin F. Harrison
#  621 : Paul H.B. Pascoe
#  622 : I. Michael Peacock OBE **
#  623 : Roger S. Silverstone
#  624 : Company Secretary
#  625 : Simon J Howell
#  626 : Registered ofﬁce
#  627 : 50 Lisson Street
#  628 : London NW1 5DF
#  629 : Nominated Adviser
#  630 : & Broker
#  631 : Seymour Pierce Limited
#  632 : Bucklersbury House
#  633 : 3 Queen Victoria Street
#  634 : London EC4N 8EL
#  635 : Solicitors to the Company
#  636 : Wragge & Co LLP
#  637 : 55 Colmore Row
#  638 : Birmingham B3 2AS
#  639 : Auditors
#  640 : PricewaterhouseCoopers Ltd
#  641 : 1 Embankment Place
#  642 : London WC2N 6RH
#  643 : Principal Bankers
#  644 : Coutts & Co
#  645 : 440 Strand
#  646 : London WC2R 0QS
#  647 : Registrars
#  648 : Capita Registrars
#  649 : The Registry
#  650 : 34 Beckenham Road
#  651 : Beckenham
#  652 : Kent BR3 4TU
#  653 : Financial Public Relations
#  654 : Portland
#  655 : 125 High Holborn
#  656 : London WC1V 6QA
#  657 : DIRECTORS AND ADVISORS
#  658 : FOR THE YEAR ENDED 31 MARCH 2005
#  659 : * K.R. Harris resigned as a director of UBC Media Group plc on 26 May 2005.
#  660 : ** I.M. Peacock retired as non-executive chairman of UBC Media Group plc on
#  661 : 18 February 2005 and is due to resign as a director of the Company at the
#  662 : AGM on 29 July 2005. 17
#  663 : ANNUAL REPORT AND ACCOUNTS 2005
#  664 : REPORT OF THE DIRECTORS
#  665 : FOR THE YEAR ENDED 31 MARCH 2005
#  666 : The directors present their report and the audited ﬁnancial statements for the year ended 31 March 2005.
#  667 : Principal activities
#  668 : The principal business of the Group is the ownership and operation of digital and analogue commercial radio stations, radio programming and the provision of
#  669 : audio and data services to the radio industry.
#  670 : Directors and their interests
#  671 : The names of the directors serving in the year and their interests at 31 March 2005 were as follows:
#  672 : At 31 March 2005, the following directors’ interests were also noted:
#  673 : 1.  Of the ordinary shares shown as beneﬁcially held by S.A. Cole, 5,000,000 are registered under
#  674 : the name of SocGen Nominees (UK) Limited.
#  675 : 2.  Of the ordinary shares shown as beneﬁcially held by T.J. Blackmore, 3,344,226 are registered
#  676 : in the name of his wife Margaret Blackmore.
#  677 : 3.  The ordinary shares shown as beneﬁcially held by N.E. Edmonds are registered under the
#  678 : name of Unique Communications Limited.
#  679 : 4.  Of the ordinary shares shown as beneﬁcially held by M.A. Honey, 63,000 are registered in
#  680 : the name of his wife, Shona Paterson, and 130,000 are registered in the name of Matthew
#  681 : & Shona Honey (ECH Trust) and 130,000 are registered in the name of Matthew & Shona
#  682 : Honey (GRH Trust).
#  683 : 5.  K.R. Harris resigned as a director of UBC Media Group plc on 26 May 2005.
#  684 : 6.  In addition to the shares held by P .H.B. Pascoe, as Chief Executive of Unique Communications
#  685 : Limited P .H.B. Pascoe is also deemed to be interested in the 13,848,714 shares held by
#  686 : that company.
#  687 : 7.  Of the ordinary shares shown as beneﬁcially held by I.M. Peacock, 3,411,000 are registered
#  688 : under the name of Investec Trustees (Jersey Limited) as trustees of the I. M. and D.J.I
#  689 : Peacock Voluntary Settlement. I.M. Peacock is due to resign as a director of UBC Media
#  690 : Group plc at the Company’s AGM on 29 July 2005.
#  691 : 8.  Of the ordinary shares shown as being under option to J.P . Quinn, M.A. Honey and J.H.
#  692 : Donald, 3,649,604 are under option to the trustees of the Company’s Employee Beneﬁt
#  693 : Trust (3,020,299 for J.H. Donald, 95,355 for M.A. Honey and 533,950 for J.P . Quinn) who
#  694 : have conﬁrmed their intention to hold the options in trust for the above named and their
#  695 : families. The Employee Beneﬁt Trust is a discretionary trust for the beneﬁt of the Company’s
#  696 : employees, former employees, their families and dependents.
#  697 : Share options
#  698 : Details of share options and warrants held by directors during the year over the ordinary shares of 1p each in the Company are set out below.
#  699 : The options were issued for no consideration.
#  700 : Options outstanding Options granted Options relinquished Options exercised Options outstanding Exercise price Date from which
#  701 : as at 1 April 2004 in year in year in year as at 31 March 2005 (pence) exercisable Expiry date
#  702 : J. H. Donald 205,000*** – – – 205,000 48.50 20/11/02 07/12/10
#  703 : K. Harris 3,000,000** – – – 3,000,000 3.13 22/06/00 30/09/05
#  704 : M. A. Honey 322,580*** – – – 322,580 31.0 02/04/03 02/04/11
#  705 : J. P . Quinn 300,000* – – – 300,000 1.03 31/03/02 30/09/06
#  706 : 2,250,000** – – – 2,250,000 1.66 26/03/00 30/09/06
#  707 : 322,580*** – – – 322,580 31.0 02/04/03 02/04/11
#  708 : *  Granted under the Unapproved Executive Share Scheme.
#  709 : ** Granted under the Unapproved Executive Share Scheme Number Two.
#  710 : *** Granted under the Enterprise Management Incentive Share Option Scheme.
#  711 : The Company’s share price as at 31 March 2005 was 29.25p and had a range of 21p to 32.25p through the year. On 20 June 2005 the Company’s share price was 25p.
#  712 : No. of ordinary shares No. of ordinary shares Ordinary shares under option
#  713 : as at 31 March 2004 as at 31 March 2005 as at 31 March 2005
#  714 : J. Hodson – – –
#  715 : S. A. Cole (1) 26,627,884 26,667,884 –
#  716 : J. H. Donald 19,225 19,225 3,225,299
#  717 : M. A. Honey (4) 4,481,429 4,481,429 417,935
#  718 : J. P . Quinn 2,850,000 2,850,000 3,406,530
#  719 : T. J. Blackmore (2) 20,080,857 20,080,857 –
#  720 : N. E. Edmonds (3) 13,848,714 13,848,714 –
#  721 : K. R. Harris (5) 3,700,000 3,700,000 3,000,000
#  722 : K.F. Harrison 2,500 2,500 –
#  723 : P . H. B. Pascoe (6) – 50,000 –
#  724 : I. M. Peacock (7) 9,431,000 9,501,000 –
#  725 : R. S. Silverstone – – – 18
#  726 : UBC MEDIA GROUP PLC
#  727 : REPORT OF THE DIRECTORS CONTINUED
#  728 : FOR THE YEAR ENDED 31 MARCH 2005
#  729 : Substantial shareholders
#  730 : At 1 June 2005 the Company has been informed of the following interests of 3% or more in its ordinary shares of 1p
#  731 : each in issue at that date:
#  732 :
#  733 : Re-election of directors
#  734 : In accordance with the Articles of Association J. Hodson, M.A. Honey, J.P . Quinn and R.S. Silverstone offer
#  735 : themselves for re-election at the forthcoming AGM, details of which are set out at the back of this annual report.
#  736 : Brief particulars of all directors can be found on page 16.
#  737 : Corporate governance
#  738 : As an AIM listed company, UBC Media Group plc is not required to comply with the main provisions of the
#  739 : principles of good governance and code of best practice prepared by the Committee on Corporate Governance
#  740 : (the ‘Combined Code’). However, insofar as they are able for a company of its size, the Board complies with the
#  741 : provisions of the Combined Code. Details concerning the Group’s arrangements relating to corporate governance
#  742 : and its compliance with the Combined Code are given on pages 19 to 20. The Directors’ Report on Remuneration
#  743 : is given on page 22.
#  744 : Annual General Meeting
#  745 : The following special business is being proposed at this year’s Annual General Meeting:
#  746 : Authority to Directors to allot shares: Resolution 8
#  747 : The Companies Act 1985 provides that the directors may not allot shares unless empowered to do so by the
#  748 : shareholders. Such a power cannot be given for longer than ﬁve years at any one time and the total nominal value
#  749 : of shares that can be allotted must be speciﬁed. In order to renew the Board’s powers in respect of unissued shares
#  750 : it is, accordingly, proposed that the directors be granted general authority at any time prior to the expiry of ﬁfteen
#  751 : months following the forthcoming Annual General Meeting (or prior to the next Annual General Meeting of the
#  752 : Company, if earlier) to allot shares up to an aggregate nominal value of £255,979 representing approximately 15%
#  753 : of the current issued share capital.
#  754 : Disapplication of pre-emption rights: Resolution 9
#  755 : This resolution is proposed for two reasons. Firstly, it renews the directors’ authority to implement rights issues
#  756 : without complying fully with the technical requirements of section 89 of the Companies Act 1985 (relating to the
#  757 : allotment of shares for cash). Secondly, the resolution gives the directors authority to allot shares for cash other
#  758 : than by way of rights to existing shareholders up to an aggregate nominal amount of £170,653. This power will
#  759 : provide the directors with the ﬂexibility to take advantage of business opportunities as they arise. Shareholders
#  760 : should note that the London Stock Exchange does not require shareholders’ speciﬁc approval for each issue
#  761 : of shares for cash on a pre-emptive basis to the extent that under section 95 of the Companies Act 1985 the
#  762 : provisions of section 89 are disapplied generally. If given, this authority will expire ﬁfteen months from the date
#  763 : of passing of the special resolution or, if earlier, on the date of the next Annual General meeting of the Company.
#  764 : Employee involvement
#  765 : The Group places considerable value on the involvement of its employees and encourages the development of
#  766 : employee involvement in each of its operating companies through both formal and informal meetings. It is the
#  767 : Group’s policy to ensure that employees are made aware of signiﬁcant matters affecting the performance of the
#  768 : Group through information bulletins, informal meetings, team brieﬁngs, internal newsletters and the Group’s
#  769 : website and intranet.
#  770 : Employee involvement
#  771 : The Group acknowledges the vital role that all employees play in its success through their skills, initiative and
#  772 : commitment. The Group endorses and supports the principles of equal opportunities and always fully considers
#  773 : applications by disabled persons. The policy in respect of staff that become disabled whilst employed is to train
#  774 : and assist them wherever practicable to continue within the Group. It is the policy of the Group to consider
#  775 : individuals on their merit and to make employment decisions on a non-discriminatory basis in compliance with its
#  776 : legal obligations. The Group’s policy is to ensure that, as far as is reasonably practicable, working environments
#  777 : exist which will minimise risk to the health and safety of employees.
#  778 : Going concern
#  779 : After reviewing the Group’s budget for the year to 31 March 2006 and its medium-term plans, the directors have a
#  780 : reasonable expectation that the Group has adequate resources to continue in operation for the foreseeable future.
#  781 : Therefore they have adopted the going concern basis in preparing the ﬁnancial statements.
#  782 : Charitable donations
# ...
#  1826 : Details of balances held with Group companies at the year-end are disclosed in notes 16 and 17. NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  1827 : FOR THE YEAR ENDED 31 MARCH 2005
#  1828 : 44
#  1829 : UBC MEDIA GROUP PLC
#  1830 : 31. FINANCIAL INSTRUMENTS CONTINUED
#  1831 : Interest risk proﬁle
#  1832 : Financial assets
#  1833 : The interest rate proﬁle of the Group’s ﬁnancial assets at 31 March 2005 was:  2005  2004
#  1834 : £’000 £’000
#  1835 : Cash and short term deposits  – ﬂoating rate  3,498  3,324
#  1836 : Short term deposits  – ﬂoating rate  –  1,000
#  1837 : Loans to joint ventures
#  1838 : – book value  458  2,300
#  1839 : 3,956  6,624
#  1840 : All of the above are in sterling.
#  1841 : At 31 March 2005, £3,498,000 was placed on overnight deposit at an average of 4.18% per annum. Floating rate cash earns interest based on the
#  1842 : relevant LIBID equivalents or government bond rates. The loans to joint ventures are interest free and repayable at the discretion of the Board of
#  1843 : The Digizone Limited.
#  1844 : Financial liabilities
#  1845 : The interest rate proﬁle of the Group’s ﬁnancial liabilities was: 2005  2004
#  1846 : £’000 £’000
#  1847 : Loans – ﬂoating rate  337  337
#  1848 : 337  337
#  1849 : The above are in sterling.
#  1850 : At 31 March 2005, the Loan – ﬂoating rate liability comprises one loan note. This was issued by Classic Gold Digital Limited to GWR plc for £337,000.
#  1851 : The loan note is to be redeemed or repaid at par on or before 1 October 2011. If the loan is repaid on or before that date then no interest accrues on
#  1852 : this loan. Otherwise interest accrues at 2% per annum above the Barclays Bank plc base rate.
#  1853 : There are no undrawn facilities at the year ended 31 March 2005.
#  1854 : There are no material differences between the fair value and the book value of the Group’s ﬁnancial assets and liabilities as at 31 March 2005 and
#  1855 : 31 March 2004.
#  1856 :
#  1857 : Maturity of ﬁnancial liabilities
#  1858 : The loan note of £337,000 issued by CGDL to GWR plc is to be redeemed or repaid at par on or before 1 October 2011.
#  1859 : 32. FUTURE LIABILITIES
#  1860 : On exercise of share options after 6 April 1999, the Company will be required to pay National Insurance on the difference between the exercise
#  1861 : price and the market value of the shares issued. As described in note 20 the options issued by the Company since 6 April 1999 will vest at various
#  1862 : dates. The Company will become unconditionally liable to pay the National Insurance upon exercise of the options. The amount of National Insurance
#  1863 : payable will depend upon the number of employees who remain with the Company and exercise their options, the market value of the Company’s
#  1864 : ordinary shares at the time of exercise and the prevailing National Insurance rate at that time. At 31 March 2005 an amount of £26,000 (2004:
#  1865 : £32,000) was provided based on the year-end share price of 29.25 pence (2004: 32 pence).   45
#  1866 : ANNUAL REPORT AND ACCOUNTS 2005
#  1867 : 34. PRINCIPAL SUBSIDIARIES, JOINT VENTURES AND ASSOCIATES
#  1868 : Ordinary shares held 2005  Ordinary shares held 2004
#  1869 : % % Principal activity
#  1870 : Subsidiaries: immediate holding company
#  1871 : UBC Media Group plc
#  1872 : The Unique Broadcasting Company Limited  100  100  Radio production and advertising sales
#  1873 : Classic Gold Digital Limited  80  80  Radio broadcasting
#  1874 : Gilmour Broadcasting Limited  75  75  Dormant
#  1875 : UBC Digital Limited  100  100  Dormant
#  1876 : Network Radio Sales Limited  100  100  Dormant
#  1877 : UBC Media Group Trustees Limited  100  100  Dormant
#  1878 : Unique Digital Limited  100  100  Dormant
#  1879 : Oneword Radio Limited  50  –  Digital radio
#  1880 : Smooth Operations (Productions) Limited  100  –  Radio production
#  1881 : Subsidiaries: immediate holding company
#  1882 : The Unique Broadcasting Company Limited
#  1883 : Unique Facilities Limited  100  100  Dormant
#  1884 : Gilmour Broadcasting Limited  25  25  Dormant
#  1885 : Unique Interactive Limited  100  100  Dormant
#  1886 : G–One Limited  50  50  Dormant
#  1887 : Oneword Radio Limited  50  –  Digital radio
#  1888 : Joint venture of UBC Media Group plc
#  1889 : The Digizone Limited   50  50  Digital data broadcasting
#  1890 : Digital News Network Limited  28  22  Provision of news programmes to digital radio
#  1891 : Joint ventures of the Unique Broadcasting Company Limited
#  1892 : Oneword Radio Limited  –  50  Digital radio
#  1893 : All subsidiaries are consolidated into the ﬁnancial information of the Group.
#  1894 : All joint ventures companies are registered in England and Wales as private companies limited by shares. The joint ventures have been included in the
#  1895 : Group accounts for the year ended 31 March 2005 using the following accounting periods:
#  1896 : The Digizone Limited  Year ended 31 March 2005
#  1897 : Digital News Network Limited  Year ended 31 March 2005
#  1898 : 33. POST BALANCE SHEET EVENTS
#  1899 : On the 6 April 2005 UBC Media Group plc sold a 51% interest in Oneword Radio Limited to Channel 4 Television Corporation for a cash consideration of £1 million. 46
#  1900 : UBC MEDIA GROUP PLC
#  1901 : NOTICE OF ANNUAL GENERAL MEETING
#  1902 : Notes:
#  1903 : 1.  A member entitled to attend and vote at the meeting may appoint one or
#  1904 : more proxies to attend and (on a poll) vote instead of him. A proxy need not
#  1905 : be a member of the Company.
#  1906 : 2.  To be effective, a proxy card must be deposited at the registered ofﬁce of
#  1907 : the Company not less than 48 hours before the time ﬁxed for the Meeting.
#  1908 : A proxy card is enclosed.
#  1909 : 3.  The Register of Directors’ Interests in shares of the Company and copies
#  1910 : of the service agreements between the Company and its Directors will be
#  1911 : available for inspection at the registered ofﬁce of the Company during usual
#  1912 : business hours on any weekday (Saturdays and public holidays excluded)
#  1913 : until the date of the Meeting and also on the date and at the place of
#  1914 : the Meeting from ﬁfteen minutes prior to its commencement until the
#  1915 : conclusion of the Meeting.
#  1916 : 4.  The Company, pursuant to Regulation 41 of the Uncertiﬁed Securities
#  1917 : Regulations 2001, speciﬁes that only shareholders registered in the register
#  1918 : of members of the Company at 11:00 am on 27 July 2005 shall be entitled
#  1919 : to attend or vote at the aforesaid annual general meeting in respect of
#  1920 : the number of shares registered in their name at that time. Changes to
#  1921 : entries in the register of members after 11:00 am on 27 July 2005 shall be
#  1922 : disregarded in determining the rights of any person to attend or vote at the
#  1923 : meeting.
#  1924 : NOTICE IS HEREBY GIVEN that the ﬁfth Annual General Meeting of the Company will be held at the ofﬁces of Wragge & Co LLP ,
#  1925 : at 3 Waterhouse Square, 142 Holborn, London EC1N 2NH on 29 July 2005 at 11.00a.m. for the following purposes:
#  1926 : Ordinary Business:
#  1927 : 1. To receive the report of the directors and the ﬁnancial statements of the Company for the year ended 31 March 2005.
#  1928 : 2.  To re-appoint PricewaterhouseCoopers LLP as auditors of the Company to hold ofﬁce until the conclusion of the next general meeting at which
#  1929 : accounts are laid before the Company and that their remuneration be ﬁxed by the directors.
#  1930 : 3.  To re-elect J. Hodson who was appointed during the year and retires in accordance with Article 86 of the Company’s Articles of Association
#  1931 : and who, being eligible, offers himself for re-election as a director.
#  1932 : 4.  To re-elect M.A. Honey who retires by rotation pursuant to Article 91 of the Company’s Articles of Association and who, being eligible, offers
#  1933 : himself for re-election as a director.
#  1934 : 5.  To re-elect J.P . Quinn who retires by rotation pursuant to Article 91 of the Company’s Articles of Association and who, being eligible, offers
#  1935 : himself for re-election as a director.
#  1936 : 6.  To re-elect R.S. Silverstone who retires by rotation pursuant to Article 91 of the Company’s Articles of Association and who, being eligible,
#  1937 : offers himself for re-election as a director.
#  1938 : 7. To approve the Directors’ Remuneration Report for the year ended 31 March 2005.
#  1939 : Special Business:
#  1940 : 8.  To consider and, if thought ﬁt, to pass the following resolution as an Ordinary Resolution:
#  1941 :
#  1942 : THAT the directors be and they are hereby generally and unconditionally authorised in accordance with section 80 of the Companies Act 1985 to exercise
#  1943 : all the powers of the Company to allot relevant securities (as deﬁned in that section) up to a maximum nominal amount of £255,979 provided that this
#  1944 : authority shall expire ﬁfteen months from the date of this resolution or, if earlier, at the conclusion of the Annual General Meeting of the Company in
#  1945 : 2006, save that the Company may before such expiry make an offer or agreement which would or might require relevant securities to be allotted after
#  1946 : such expiry and the directors may allot relevant securities in pursuance of such offer or agreement as if the authority conferred hereby had not expired.
#  1947 : 9.  To consider and, if thought ﬁt, to pass the following resolution as a Special Resolution:
#  1948 :
#  1949 : THAT, subject to and conditionally upon the passing of resolution No.8 above, the directors be and they are hereby empowered pursuant to section 95 of
#  1950 : the Companies Act 1985 to allot equity securities (as deﬁned in section 94 (2) of that Act) for cash pursuant to the authority conferred by that resolution
#  1951 : as if section 89 (1) of the said Act did not apply to such allotment, PROVIDED that the power hereby conferred shall be limited:
#  1952 : i)  to the allotment of equity securities in connection with a rights issue in favour of shareholders where the equity securities respectively attributable
#  1953 : to the interests of all shareholders are proportionate (as nearly as may be) to their holdings of such shares subject to such exclusions or entitlements,
#  1954 : statutory restrictions or legal or practical problems under or resulting from the application of the laws of any territory or the requirements of any
#  1955 : recognised regulatory body or stock exchange in any territory, and
#  1956 : ii)    to the allotment (otherwise than pursuant to the sub-paragraph (i) above) of equity securities up to an aggregate nominal amount of £170,653 being
#  1957 : 10% of the issued share capital as shown by the latest published annual accounts of the Company;
#  1958 : and shall expire ﬁfteen months from the date of this resolution or, if earlier, at the conclusion of the Annual General Meeting of the Company in 2006,
#  1959 : save that the Company may before such expiry make an offer or agreement which would or might require equity securities to be allotted after such
#  1960 : expiry and the directors may allot equity securities in pursuance of such offer or agreement as if the power conferred hereby had not expired.
#  1961 : Dated 20 June 2005
#  1962 : By Order of the Board,
#  1963 :
#  1964 :
#  1965 :
#  1966 : S.J. Howell, Company Secretary
#  1967 : Registered Ofﬁce: 50 Lisson Street, London NW1 5DF 47
#  1968 : PROXY FORM 2005 - UBC MEDIA GROUP PLC
#  1969 : Notes
#  1970 : 1. A proxy need not be a member of the Company.
#  1971 : 2.  In the case of joint holders, the vote of the senior who tenders a vote, whether in person or by proxy, will be
#  1972 : accepted to the exclusion of the votes of the other joint holders. For this purpose seniority is determined by the
#  1973 : order in which the names stand in the Register of Members in respect of the joint holding.
#  1974 : 3.  In the case of a corporation this proxy must be given under its common seal or be signed on its behalf by an
#  1975 : attorney or ofﬁcer duly authorised.
#  1976 : 4.  To be effective, this form must be lodged at the address overleaf not later than 48 hours before the time of the
#  1977 : Meeting, or any adjournment thereof, together, if appropriate, with the power of attorney or other authority
#  1978 : under which it is signed or a notarially certiﬁed copy of such power or, where the form has been signed by an
#  1979 : ofﬁcer on behalf of a corporation, a notarially certiﬁed copy of the authority under which it is signed.
#  1980 : 5. Any alterations made on this form should be initialled.
#  1981 : 6.  Please indicate with an X how you wish your votes cast. Unless otherwise instructed, the proxy will vote or
#  1982 : abstain as the proxy thinks ﬁt. On any motion to amend any resolution, to propose a new resolution, to adjourn
#  1983 : the Meeting, or any other motion put to the Meeting the proxy will act at his/her/their discretion.
#  1984 : 7.  If it is desired to appoint as proxy any person other than the Chairman of the Meeting, his/her name and address
#  1985 : should be inserted in the relevant place, reference to the Chairman deleted and the alteration initialled.
#  1986 : 8.  The completion and return of this form will not prevent you from attending in person and voting at the Meeting
#  1987 : should you subsequently decide to do so.
#  1988 : Tear along perforation
#  1989 : For use by Shareholders at the Annual General Meeting, to be held on 29 July 2005
#  1990 :
#  1991 : Please ﬁll in form using BLOCK CAPITALS.
#  1992 : I/We (name in full)
#  1993 : of
#  1994 : being (a) holder(s) of ordinary Shares of 1p each of the Company, hereby appoint the duly appointed
#  1995 : Chairman* of the Meeting or
#  1996 : (insert name and address)
#  1997 : to act as my/our proxy at the Annual General Meeting of the Company to be held on 29 July 2005, and at any
#  1998 : adjournment thereof.
#  1999 : *see Note 7 below
#  2000 : Please mark X how you wish your votes to be cast (see Note 6)
#  2001 : RESOLUTIONS FOR AGAINST
#  2002 : Ordinary business
#  2003 : 1. To receive the Directors’ Report and Accounts
#  2004 : 2. To re-appoint auditors
#  2005 : 3. To re-elect J. Hodson as a Director
#  2006 : 4. To re-elect M.A. Honey as a Director
#  2007 : 5. To re-elect J.P . Quinn as a Director
#  2008 : 6. To re-elect R.S. Silverstone as a Director
#  2009 : 7. To approve the Directors’ Renumeration Report
#  2010 : Special business
#  2011 : 8. To give an allotment authority
#  2012 : 9. To disapply pre-emption rights
#  2013 :
#  2014 : Date 2005
#  2015 :
#  2016 :
#  2017 : Signature 1   Fold along this line ﬁrst
#  2018 : 2   Fold along this line second
#  2019 : 3   Fold along this line third
#  2020 : 01 Financial highlights
#  2021 : 02 Chairman’s statement
#  2022 : 03 Chief Executive’s statement
#  2023 : 04 Commissioned programming
#  2024 : 06 Syndicated programming
#  2025 : 08 Radio stations
#  2026 : 10 Radio services
#  2027 : 12 Financial review
#  2028 : 16 Board of directors
#  2029 : 16 Directors and advisors
#  2030 : 17 Report of the directors
#  2031 : 19 Corporate governance statement
#  2032 : 21 Statement of directors’ responsibilities
#  2033 : 22 Remuneration report
#  2034 : 23 Independent auditors’ report
#  2035 : 24 Consolidated proﬁt and loss account
#  2036 : 25 Consolidated balance sheet
#  2037 : 26 Company balance sheet
#  2038 : 27 Consolidated cash ﬂow statement
#  2039 : 28 Notes to the ﬁnancial statements
#  2040 : 46 Notice of AGM
#  2041 : *Before goodwill and digital licences
#  2042 : 01
#  2043 : -519
#  2044 : 04
#  2045 : 13.29
#  2046 : 03
#  2047 : 10.32
#  2048 : 02
#  2049 : 9.19
#  2050 : 01
#  2051 : 6.18
#  2052 : 05
#  2053 : 15.96
#  2054 : -210
#  2055 : 02
#  2056 : 73
#  2057 : 03
#  2058 : 405
#  2059 : 04
#  2060 : 1,075
#  2061 : 05
#  2062 : GROUP TURNOVER
#  2063 : £ millions
#  2064 : OPERATING PROFIT/(LOSS)*
#  2065 : £ thousands UBC MEDIA GROUP PLC
#  2066 : ANNUAL REPORT & ACCOUNTS 2005
#  2067 : UBC MEDIA GROUP PLC  ANNUAL REPORT AND ACCOUNTS 2005
#  2068 : UBC Media Group PLC
#  2069 : 50 Lisson Street
#  2070 : London NW1 5DF
#  2071 : T: 020 7453 1600
#  2072 : F: 020 7723 6132

# %%
def remove_invalid_sentences(sentences_list):

    # Check if the sentence contains only numbers, single letters, only punctuation, or specific symbols
    def is_valid(sentence):
        return not re.match(r'^[0-9a-zA-Z]*[a-zA-Z][0-9a-zA-Z]*$', sentence) \
               and not re.search(r'\b\d{1,3}(,\d{3})*\b|\b\d{4}\b', sentence) \
               and '£' not in sentence

    valid_sentences = [sentence for sentence in sentences_list if is_valid(sentence)]

    return valid_sentences
# Call the function to remove invalid sentences
clean_sentences = remove_invalid_sentences(sentences_lower)

# Print the valid sentences
print("Valid Sentences:")
for i, clean_sentence in enumerate(clean_sentences):
    print(f" {i+1}: {clean_sentence}")
# Out:
# Valid Sentences:
#  1: UBC MEDIA GROUP PLC
#  2: UBC Media Group PLC
#  3: London NW1 5DF
#  4: *Before goodwill and digital licences
#  5: GROUP TURNOVER
#  6: OPERATING PROFIT/(LOSS)*
#  7: RADIO SECTOR. UBC’S RADIO STATIONS INCLUDE THE NATIONAL DIGITAL
#  8: STATIONS, CLASSIC GOLD DIGITAL AND ONEWORD RADIO. UBC IS ALSO A
#  9: LEADING SUPPLIER OF RADIO SERVICES, INCLUDING SOFTWARE TO OPERATE
#  10: DIGITAL RADIO DATA SERVICES. IN ADDITION, UBC RANKS AS THE LEADING
#  11: INDEPENDENT SUPPLIER OF RADIO PROGRAMMES TO THE BBC AND THE
#  12: COMMERCIAL RADIO INDUSTRY.
#  13: GOLD DIGITAL
#  14: GOLD DIGITAL
#  15: UBC MEDIA GROUP PLC
#  16: CHAIRMAN’S STATEMENT
#  17: John Hodson Chairman
#  18: This is the ﬁrst opportunity I have had to write to the shareholders of
#  19: UBC Media Group since my appointment as Chairman of the Company in
#  20: As the new Chairman I think it is helpful to reiterate the strategy that has
#  21: to maximise the returns from UBC’s traditional businesses as a means to ﬁnance
#  22: the Group’s digital expansion, including the signiﬁcant programme of investment
#  23: in its portfolio of digital assets.
#  24: In keeping with UBC’s strategy, I am delighted to report another year of strong
#  25: The growth in the past year reﬂects a combination of both organic growth and
#  26: acquisitions, with positive contributions from all the Group’s main divisions.
#  27: Full details of the performance of each of the Group’s divisions are contained in
#  28: the Financial Review.
#  29: I would like to take this opportunity to extend the thanks of the board to my
#  30: predecessor, Michael Peacock, who performed the role of chairman of UBC with
#  31: business has been enormous, bringing to UBC all the experience gained from a
#  32: long and distinguished career in the media industry. On behalf of my colleagues
#  33: I would like to express my appreciation to Michael for all he has done to guide
#  34: UBC to where it is today and to wish him a long and well deserved retirement.
#  35: Following his decision to stand down as a director, I would also like to thank
#  36: Keith Harris on behalf of the rest of the Board for his long standing contribution
#  37: to the Company, and most recently for his services as a director of UBC.
#  38: The commercial and creative successes of the past year could not have been
#  39: achieved without the enthusiasm and commitment of the whole team at UBC.
#  40: The Company has a highly talented workforce and it is their consistent and
#  41: focused efforts that have enabled us to deliver a further year of strong growth.
#  42: UBC is founded on a culture of innovation and creativity and the strong
#  43: performance of the past year is evidence of the robust and complementary mix of
#  44: businesses within the Group. The Company is led by an established management
#  45: team that is young and energetic, and with ambitions to grow the business
#  46: substantially over the next few years. I believe that with a continuing favourable
#  47: environment the prospects for the Company in the current year are good.
#  48:
#  49: John Hodson
#  50: Chairman I am pleased to be able to report a further year of strong growth for UBC
#  51: Media Group, delivering on our past commitment to shareholders and
#  52: putting in place a robust foundation for the next stage in the development
#  53: of your company.
#  54: Digital radio is now a success story, with the UK leading the world. Key skills for
#  55: exploiting the digital marketplace are the supply of content, control of spectrum
#  56: and software development. UBC is well placed in each of these areas, with skills
#  57: and experience, as is evident from a number of developments during the last
#  58: year, both in the UK and overseas.
#  59: The high growth digital radio environment that we anticipated and around which
#  60: we have built UBC is now upon us. DAB is proving to be one of the fastest ever
#  61: new technologies to reach mass market status and the industry’s forecasts
#  62: for take-up this year are currently being revised upwards. UBC has sought to
#  63: create the right business mix for an environment that we believe will operate on
#  64: different economic models from that of the traditional analogue radio world.
#  65: The creation of strong brands is of growing importance in what is an increasingly
#  66: Television in our national digital radio station, Oneword Radio, is of particular
#  67: signiﬁcance, and also demonstrates the increasing value of ownership of digital
#  68: radio licences.
#  69: As we predicted, networking and the ability to generate revenues by providing
#  70: programming to stations owned by others is becoming a key part of the digital
#  71: radio economy. It is in this area that we have seen particularly strong growth in
#  72: regional independent production company, Smooth Operations, has made an
#  73: programming. We continue to be one of the leading suppliers of programmes
#  74: to the BBC and the value of this position is ampliﬁed by the BBC’s intention to
#  75: double the programming it commissions from independent production companies.
#  76: Whilst we welcome a step that will beneﬁt our production businesses, it will
#  77: still leave radio outsourcing signiﬁcantly behind that of television. We see no
#  78: CHIEF EXECUTIVE’S STATEMENT
#  79: justiﬁcation for this, and are lobbying government as part of the current Charter
#  80: Review process to encourage greater movement from the BBC.
#  81: Digital radio offers the opportunity to bring real vision to the radio industry. UBC
#  82: Media Group’s strategy has been to anticipate how digital radio will develop,
#  83: and position the Company to beneﬁt from new opportunities as they emerge.
#  84: We believe the ability to transmit data will be one of the key drivers of the
#  85: market share for the provision of software to drive the existing text services that
#  86: accompany digital radio broadcasts. This, however, is only the beginning: devices
#  87: are now being launched which allow full Electronic Programme Guides (EPG) and
#  88: facilitate sophisticated services using digital radio’s data capacity.
#  89: UBC has the only commercially available EPG software in the UK and has already
#  90: licensed this to major UK broadcasters, including GCap Media and the recently
#  91: announced BT Livetime datacasting venture. A major part of our investment in
#  92: UBC and, in particular, on the launch of innovative services that allow music to
#  93: be downloaded over digital radio. We expect to launch such a service in the
#  94: next calendar year.
#  95: UBC’s aim continues to be to grow the business both organically and by
#  96: acquisition. We remain committed to investing in the development of
#  97: our portfolio of digital assets and to maintaining our position at the
#  98: forefront of innovation and technical achievement. Since the start of
#  99: the new ﬁnancial year, as has been widely reported elsewhere, the
#  100: radio advertising market has shown signs of softening. However,
#  101: we continue to see advertising revenues higher than at this
#  102: time last year. The Group continues to perform in line with
#  103: expectations and we believe the prospects for the year
#  104: ahead are positive.
#  105: Simon Cole
#  106: Chief Executive
#  107: UBC IS THE LARGEST INDEPENDENT RADIO PRODUCTION
#  108: OF COMMISSIONED PROGRAMMING FOR THE BBC.
#  109: REGIONAL INDEPENDENT PRODUCTION COMPANY. THE INTEGRATION OF
#  110: SMOOTH OPERATIONS HAS PROGRESSED WELL AND IN THE LAST YEAR THE
#  111: GROUP HAS SEEN STRONG GROWTH IN REVENUES FROM COMMISSIONED
#  112: PROGRAMMING TO THE BBC. UBC IS WELL POSITIONED TO TAKE ADVANTAGE OF
#  113: THE BBC’S PLANS TO INCREASE BOTH ITS REGIONAL OUTPUT AND THE AMOUNT
#  114: OF INDEPENDENTLY PRODUCED PROGRAMMING IT BROADCASTS.  UBC RANKS AS ONE OF THE LARGEST SUPPLIERS OF SYNDICATED
#  115: PROGRAMMES TO COMMERCIAL RADIO – SUPPLYING BOTH THE
#  116: NETWORK DRIVE AND ENTERTAINMENT NEWS SERVICES.
#  117: STRONG GROWTH AS A RESULT OF COMBINING UBC’S AND EMAP’S
#  118: SYNDICATED RADIO AIRTIME SALES NETWORKS AND THE LAUNCH OF A
#  119: CONSOLIDATED TRAFFIC AND TRAVEL SERVICE. THE MARKET FOR UBC’S
#  120: SYNDICATED RADIO PROGRAMMING CONTINUES TO BE STRONG AS THE
#  121: COMMERCIAL RADIO SECTOR INCREASINGLY RECOGNISES ITS NEED TO
#  122: INVEST IN HIGH–QUALITY PROGRAMMING.
#  123: PRIME ASSETS IN DIGITAL RADIO.
#  124: CLASSIC GOLD DIGITAL RANKS AS ONE OF THE TOP ‘GOLD’
#  125: FORMATS IN THE UK, AND IS BROADCAST ON BOTH ANALOGUE
#  126: AND DIGITAL PLATFORMS, REACHING A POTENTIAL UK ADULT
#  127: ONLY COMMERCIAL DIGITAL SPOKEN–WORD LICENCE. WE
#  128: OWNERSHIP OF ONEWORD RADIO IS A KEY DEVELOPMENT IN
#  129: THE GROWTH OF DIGITAL RADIO IN THE UK.
#  130: SERVICES WILL FUNDAMENTALLY CHANGE THE DEVELOPMENT
#  131: OF DIGITAL RADIO.
#  132: UBC EXPECTS THE NEXT FEW YEARS WILL SEE THE LAUNCH OF A NEW
#  133: GENERATION OF RADIO RECEIVERS CAPABLE OF DELIVERING SERVICES
#  134: EPG–ENABLED DEVICES WILL BE FOLLOWED BY THE LAUNCH OF NEW
#  135: RADIO SERVICES, SUCH AS MUSIC DOWNLOADING. UBC’S OWNERSHIP
#  136: OF DATA SPECTRUM AND EXPERIENCE IN RADIO SOFTWARE SERVICES
#  137: PLACES THE GROUP AT THE FOREFRONT OF THIS MARKET.
#  138: UBC MEDIA GROUP PLC
#  139: Financial highlights
#  140: The main ﬁnancial highlights of UBC Media Group for the year to
#  141: –  Operating Proﬁt for the year before goodwill and digital licences
#  142: –  Operating Proﬁt, excluding goodwill and investment in Oneword Radio
#  143: which includes the Company’s investment in Oneword Radio’s digital
#  144: licence while it was a subsidiary company.
#  145: Financial performance by division
#  146: UBC’s Production Division encompasses both the Group’s commissioned
#  147: radio programming for the BBC and syndicated programming for the
#  148: commercial radio industry.
#  149: Commissioned Programming
#  150:
#  151: UBC’s commissioned programming business for the BBC comprises the
#  152: Group’s historic production business, Unique, and the leading regional
#  153: independent production company, Smooth Operations, which UBC
#  154: The integration of Smooth Operations, which operates from ofﬁces in
#  155: Manchester and Cambridge, has progressed well and Unique continues
#  156: to recover from the expiry of one of its long-standing commissions
#  157: at the start of the ﬁnancial year. Turnover for the year was ahead by
#  158: Unique and Smooth Operations produce a wide range of programmes
#  159: for broadcast across the BBC’s network of national analogue and digital
#  160: programming for the BBC per year across a number of genres, with much
#  161: of their output as long-term commissions for some of the BBC’s ﬂagship
#  162: radio programmes. As an indication of the creative skills within the
#  163: Group, this year UBC received a record number of Sony Radio Academy
#  164: nominations for its programmes, including winning two prestigious Sony
#  165: Radio Academy Gold Awards.
#  166: The acquisition of Smooth Operations, which specialises in the Folk
#  167: and Country music genres, was an important strategic move by UBC in
#  168: a sector that it knows well and where prospects for signiﬁcant organic
#  169: growth have historically been limited. The strategic importance of
#  170: the acquisition of Smooth Operations was underlined by the BBC’s
#  171: in production resources in Manchester. In addition, UBC believes both
#  172: Unique and Smooth Operations are well positioned to beneﬁt from
#  173: the BBC’s announcement during the year that it intends to double
#  174: the number of hours allocated to independent radio production by its
#  175: national radio networks.
#  176: FINANCIAL REVIEW
#  177: Syndicated Programming
#  178:
#  179: UBC operates two networks of syndicated programmes, Entertainment
#  180: News and the Network Drive trafﬁc & travel service, both of which UBC
#  181: supplies free of charge to radio stations across the UK while retaining
#  182: airtime within each bulletin which is then available to UBC to sell to
#  183: national advertisers.
#  184: airtime sales business followed a doubling of revenues from syndicated
#  185: The signiﬁcant increase in airtime sales revenues in the year reﬂects
#  186: in particular the substantial growth of the trafﬁc & travel news service
#  187: consolidated their competing trafﬁc & travel services into a combined
#  188: by UBC. The network was relaunched in August as one of the largest
#  189: appointment of Trafﬁclink as sole supplier of trafﬁc and travel data to
#  190: the Network Drive service.
#  191: We believe that in the future syndicated programming will become an
#  192: increasingly important feature of the commercial radio market. The
#  193: growth in digital radio will result in there being more radio stations in
#  194: each market, and in response to market fragmentation advertisers will
#  195: seek advertising properties that deliver national reach. One of the main
#  196: challenges facing radio groups in this changed environment will be how
#  197: to provide cost effective, high-quality programming, and in particular
#  198: programming which can compete against the BBC’s output. UBC believes
#  199: that networked programming is likely to form an important part of the
#  200: solution to these competitive challenges.
#  201: As a consequence, UBC is continuing to explore ways in which to grow
#  202: which is also broadcast on MTV. As part of its investment UBC became
#  203: Popworld’s radio partner with exclusive responsibility for exploitation
#  204: of the Popworld brand through networked programming to commercial
#  205: radio stations.
#  206: RADIO STATIONS
#  207: UBC’s two main radio stations are Classic Gold Digital, which broadcasts
#  208: a Classic Hits format on a network of analogue and digital platforms
#  209: across the UK, and the national, digital spoken-word radio station,
#  210: Oneword Radio.
#  211: Classic Gold Digital
#  212:
#  213: Classic Gold Digital Limited performed in line with expectations in the
#  214: Classic Gold Digital’s revenues are directly based upon the network’s
#  215: audience as measured by RAJAR, in the form of an audience fee that
#  216: GCap Media pays to Classic Gold Digital in return for it selling airtime
#  217: on the network. The RAJAR results during the year for Classic Gold
#  218: Digital have shown a modest decline in audiences. Overall, the long-
#  219: term decline in audiences common to radio services broadcast on AM
#  220: frequencies has been partially compensated for by growth in digital
#  221: audiences. As part of its long-term strategy to maintain audiences,
#  222: Classic Gold Digital has continued to invest throughout the year in high
#  223: quality programming output and marketing.
#  224: The RAJAR report for the ﬁnal quarter of the ﬁnancial year ended
#  225: In addition, the number of listeners in areas where Classic Gold Digital
#  226: growth of digital listening, one of the key challenges facing the radio
#  227: industry in the forthcoming year will be educating advertisers to place
#  228: equal value on both analogue and digital listening.
#  229: to increase its shareholding in Classic Gold Digital from its current
#  230: its shareholding in Classic Gold Digital is based on a formula agreed
#  231: Media of any plans to increase its shareholding in Classic Gold Digital.
#  232: Oneword Radio
#  233: of ensuring the long-term future of the station. As a consequence of
#  234: taking full control of Oneword Radio, the results of UBC for the year to
#  235: UBC MEDIA GROUP PLC
#  236: As a result of a restructuring programme that took place at the same
#  237: time that UBC acquired full control of Oneword Radio, the cost of
#  238: operating Oneword Radio was closely controlled throughout the year.
#  239: At the same time it has shown steady audience growth year-on-year,
#  240: It was UBC’s intention when it acquired full control of Oneword Radio
#  241: to identify a strategic partner for the station with a shared vision of
#  242: the prospects for digital radio in the UK. Following the ﬁnancial year-
#  243: investment in Oneword Radio will reduce in the current year following
#  244: currently working on plans jointly to develop Oneword Radio; building
#  245: on what we believe is a valuable digital asset that has signiﬁcant
#  246: growth prospects.
#  247: RADIO SERVICES
#  248: UBC’s Radio Services division comprises the Group’s digital software
#  249: development and facilities businesses.
#  250:
#  251: turnover experienced by Radio Services reﬂects a further fall in turnover
#  252: from the Group’s facilities and studios business as we continue to focus
#  253: on higher margin business in this area. This was partly compensated for
#  254: radio industry.
#  255: Unique Interactive
#  256: Unique Interactive continues to beneﬁt from the increasing investment by
#  257: both UK and overseas radio broadcasters in their digital services. Unique
#  258: Interactive’s development focus continues to be on the Group’s two main
#  259: software products: the ‘ManDLS’ software, which is used to manage the
#  260: scrolling text (Dynamic Label Segment) of a digital radio service; and the
#  261: development of software to operate electronic programme guide (EPG)
#  262: services which form part of the interactive capabilities of an emerging
#  263: new generation of EPG-enabled digital devices.
#  264: Unique Interactive’s EPG software continues to be the only commercially
#  265: available radio EPG, and it was a key element in the launch of the ﬁrst
#  266: that the launch of EPG-capable digital radios will signiﬁcantly change
#  267: the way that broadcasters and listeners utilise digital radio, and that
#  268: in the future digital radios will incorporate features as standard which
#  269: will transform the capabilities of the medium, such as rewind, record
#  270: and download. These will enable additional access to a signiﬁcantly
#  271: enhanced range of information services, and will change the current
#  272: common perception that digital radio is only about greater listener
#  273: choice and better sound quality.
#  274: Unique Interactive is a market leader in software development for digital
#  275: radio services as a result of its early investment in this area and it is
#  276: currently developing an increasing international proﬁle in the delivery of
#  277: software solutions to the industry. Unique Interactive is currently working
#  278: with a number of leading broadcasting and technology companies in
#  279: developments that will reinforce UBC’s prominence in this area.
#  280: Since the year-end UBC has announced its intention to invest
#  281: creating an innovative service which will allow music to be downloaded
#  282: over digital radio. The music downloading service will utilise data
#  283: capacity on a number of digital radio multiplexes that are owned by UBC.
#  284: The Company has begun negotiation with partners in the music and radio
#  285: industries with whom it will work on bringing this service to market. The
#  286: Company’s plans in this area are still at an early stage of development,
#  287: but it is intended that investors will be updated on progress at the time
#  288: Unique Facilities
#  289: Unique Facilities delivered a satisfactory performance in the year to
#  290: on the back of good occupancy rates. Despite operating in a highly
#  291: competitive market, UBC’s facilities have operated at full capacity for
#  292: extended periods during the year. In addition, Unique Facilities has
#  293: sought to extend its audio creative services, with the successful launch
#  294: of a number of new products, including the composition of theme and
#  295: incidental music for television programmes and bespoke music jingles.
#  296: Acquisitions & disposals
#  297: million new UBC ordinary shares.
#  298: which broadcasts a regional data service on ﬁve MXR multiplexes, from
#  299: a leading UK independent regional radio producer. The acquisition
#  300: shares satisﬁed the initial acquisition consideration, plus costs incurred
#  301: ordinary shares. The ﬁrst part of the deferred consideration will become
#  302: and new UBC ordinary shares.
#  303: shareholding in Popworld Limited, which owns and controls the
#  304: The option was not exercised.
#  305: of a national television and commercial radio station and potentially
#  306: mirrors the BBC’s ownership of a cross-media brand. UBC and Channel
#  307: brand name.
#  308: Fund Raising and use of proceeds
#  309: expenses) for the Company. The net proceeds of the placing were
#  310: used to satisfy the initial cash consideration and related costs of the
#  311: Limited. The balance of the proceeds will be used to fund the balance of
#  312: any deferred cash consideration of the acquisition.
#  313: Investment in digital radio
#  314: in digital licences:
#  315: Classic Gold Digital on digital multiplexes covering Northern England
#  316: and Greater London and other areas which broaden Classic Gold
#  317: regional data services on ﬁve MXR digital multiplexes.
#  318: Oneword Radio.
#  319: Cash Flow
#  320: During the year UBC had a cash inﬂow from operating activities after
#  321: digital licences and before investment in Oneword Radio and working
#  322: International Financial Reporting Standards (IFRS)
#  323: As a result of a review of its accounting policies it is UBC Media Group’s
#  324: Payment of Dividend
#  325: The Board is not recommending the payment of a dividend.
#  326: Jennifer Donald
#  327: UBC MEDIA GROUP PLC
#  328: BOARD OF DIRECTORS
#  329: John Hodson was appointed to the Board as Non-Executive Chairman of the
#  330: of Singer & Friedlander Group. Other non-executive directorships held by John
#  331: include Domino’s Pizza UK & IRL plc and Prestbury Group. John is Chairman of
#  332: the Nominations Committee and a member of the Remuneration Committee.
#  333: Blackmore, having pioneered the market for national sponsored programmes
#  334: whilst at Piccadilly Radio, where he was Head of Programmes. Simon has
#  335: been awarded a fellowship of the Radio Academy. Simon is a member of
#  336: the Nominations Committee.
#  337: Jennifer Donald qualiﬁed as a chartered accountant with KPMG and has
#  338: held directorships in a number of private and publicly owned companies.
#  339: of McCarthy Corporation plc. Jennifer is a member of the Nominations
#  340: Committee.
#  341: Matthew Honey is Managing Director of Unique Interactive, with
#  342: responsibility for the Group’s Radio Services activities. Matthew joined
#  343: of the Group. Matthew qualiﬁed as a chartered accountant with Coopers
#  344: & Lybrand.
#  345: John Quinn has overall responsibility for the Group’s commercial airtimes sales.
#  346: Editorial Director
#  347: a career in radio production with BBC Radio One and Capital Radio. In April
#  348: from day-to-day executive responsibilities. He continues to act as Group
#  349: Editorial Director for UBC Media Group and as Chairman of Classic Gold
#  350: Digital and Smooth Operations and as a director of Oneword Radio. Tim
#  351: served as the ﬁrst Director of the Radio Academy and was awarded an
#  352: MBE for services to independent radio production. Tim has also been awarded
#  353: a fellowship of the Radio Academy and is Chairman of the Sony Radio
#  354: Academy Awards.
#  355: the Unique Group of companies, a privately owned media and communications
#  356: group engaged in television and event production, video communication and
#  357: talent management.
#  358: Kelvin Harrison is a chartered engineer with signiﬁcant experience of the
#  359: software, electronics and communications sectors in various positions,
#  360: including chief executive of public and private companies. Kelvin is also Chief
#  361: Executive of Maxima Holdings plc. Kelvin is Chairman of the Remuneration
#  362: Committee and a member of the Audit Committee.
#  363: Paul Pascoe is Chief Executive Ofﬁcer of the Unique Group of companies,
#  364: which are engaged in television and event production, video communication
#  365: and talent management. Paul serves as a Non-Executive Director of UBC
#  366: Media Group and is Chairman of the Audit Committee and a member of the
#  367: Remuneration Committee.
#  368: Michael Peacock stood down as Non-Executive Chairman of UBC Media
#  369: Non-Executive Director of UBC Media Group at the Company’s AGM in July
#  370: positions held by him include Managing Director of London Weekend
#  371: Television and Executive Vice President of Warner Bros TV. Michael is also a
#  372: an OBE in the Queen’s Birthday Honours for services to higher education.
#  373: Remuneration committees.
#  374: Roger Silverstone is Professor of Media and Communications at the London
#  375: School of Economics, having previously worked in television research and
#  376: production for London Weekend Television, Associated Television and the
#  377: BBC. Roger is a member of the Audit and Remuneration committees.
#  378: Executive directors
#  379: Simon A Cole
#  380: Jennifer H Donald
#  381: Matthew A Honey
#  382: John P Quinn
#  383: Non-executive directors
#  384: John Hodson
#  385: Timothy J. Blackmore MBE
#  386: Noel E. Edmonds
#  387: Keith R. Harris *
#  388: Kelvin F. Harrison
#  389: Paul H.B. Pascoe
#  390: I. Michael Peacock OBE **
#  391: Roger S. Silverstone
#  392: Company Secretary
#  393: Simon J Howell
#  394: Registered ofﬁce
#  395: London NW1 5DF
#  396: Nominated Adviser
#  397: & Broker
#  398: Seymour Pierce Limited
#  399: Bucklersbury House
#  400: London EC4N 8EL
#  401: Solicitors to the Company
#  402: Wragge & Co LLP
#  403: Birmingham B3 2AS
#  404: PricewaterhouseCoopers Ltd
#  405: London WC2N 6RH
#  406: Principal Bankers
#  407: Coutts & Co
#  408: London WC2R 0QS
#  409: Capita Registrars
#  410: The Registry
#  411: Kent BR3 4TU
#  412: Financial Public Relations
#  413: London WC1V 6QA
#  414: DIRECTORS AND ADVISORS
#  415: ** I.M. Peacock retired as non-executive chairman of UBC Media Group plc on
#  416: REPORT OF THE DIRECTORS
#  417: Principal activities
#  418: The principal business of the Group is the ownership and operation of digital and analogue commercial radio stations, radio programming and the provision of
#  419: audio and data services to the radio industry.
#  420: Directors and their interests
#  421: the name of SocGen Nominees (UK) Limited.
#  422: in the name of his wife Margaret Blackmore.
#  423: name of Unique Communications Limited.
#  424: Honey (GRH Trust).
#  425: that company.
#  426: under the name of Investec Trustees (Jersey Limited) as trustees of the I. M. and D.J.I
#  427: Peacock Voluntary Settlement. I.M. Peacock is due to resign as a director of UBC Media
#  428: have conﬁrmed their intention to hold the options in trust for the above named and their
#  429: families. The Employee Beneﬁt Trust is a discretionary trust for the beneﬁt of the Company’s
#  430: employees, former employees, their families and dependents.
#  431: Share options
#  432: Details of share options and warrants held by directors during the year over the ordinary shares of 1p each in the Company are set out below.
#  433: The options were issued for no consideration.
#  434: Options outstanding Options granted Options relinquished Options exercised Options outstanding Exercise price Date from which
#  435: *  Granted under the Unapproved Executive Share Scheme.
#  436: ** Granted under the Unapproved Executive Share Scheme Number Two.
#  437: *** Granted under the Enterprise Management Incentive Share Option Scheme.
#  438: No. of ordinary shares No. of ordinary shares Ordinary shares under option
#  439: J. Hodson – – –
#  440: UBC MEDIA GROUP PLC
#  441: REPORT OF THE DIRECTORS CONTINUED
#  442: Substantial shareholders
#  443: each in issue at that date:
#  444:
#  445: Re-election of directors
#  446: In accordance with the Articles of Association J. Hodson, M.A. Honey, J.P . Quinn and R.S. Silverstone offer
#  447: themselves for re-election at the forthcoming AGM, details of which are set out at the back of this annual report.
#  448: Corporate governance
#  449: As an AIM listed company, UBC Media Group plc is not required to comply with the main provisions of the
#  450: principles of good governance and code of best practice prepared by the Committee on Corporate Governance
#  451: (the ‘Combined Code’). However, insofar as they are able for a company of its size, the Board complies with the
#  452: provisions of the Combined Code. Details concerning the Group’s arrangements relating to corporate governance
#  453: Annual General Meeting
#  454: The following special business is being proposed at this year’s Annual General Meeting:
#  455: shareholders. Such a power cannot be given for longer than ﬁve years at any one time and the total nominal value
#  456: of shares that can be allotted must be speciﬁed. In order to renew the Board’s powers in respect of unissued shares
#  457: it is, accordingly, proposed that the directors be granted general authority at any time prior to the expiry of ﬁfteen
#  458: months following the forthcoming Annual General Meeting (or prior to the next Annual General Meeting of the
#  459: of the current issued share capital.
#  460: This resolution is proposed for two reasons. Firstly, it renews the directors’ authority to implement rights issues
#  461: allotment of shares for cash). Secondly, the resolution gives the directors authority to allot shares for cash other
#  462: provide the directors with the ﬂexibility to take advantage of business opportunities as they arise. Shareholders
#  463: should note that the London Stock Exchange does not require shareholders’ speciﬁc approval for each issue
#  464: of passing of the special resolution or, if earlier, on the date of the next Annual General meeting of the Company.
#  465: Employee involvement
#  466: The Group places considerable value on the involvement of its employees and encourages the development of
#  467: employee involvement in each of its operating companies through both formal and informal meetings. It is the
#  468: Group’s policy to ensure that employees are made aware of signiﬁcant matters affecting the performance of the
#  469: Group through information bulletins, informal meetings, team brieﬁngs, internal newsletters and the Group’s
#  470: website and intranet.
#  471: Employee involvement
#  472: The Group acknowledges the vital role that all employees play in its success through their skills, initiative and
#  473: commitment. The Group endorses and supports the principles of equal opportunities and always fully considers
#  474: applications by disabled persons. The policy in respect of staff that become disabled whilst employed is to train
#  475: and assist them wherever practicable to continue within the Group. It is the policy of the Group to consider
#  476: individuals on their merit and to make employment decisions on a non-discriminatory basis in compliance with its
#  477: legal obligations. The Group’s policy is to ensure that, as far as is reasonably practicable, working environments
#  478: exist which will minimise risk to the health and safety of employees.
#  479: Going concern
#  480: reasonable expectation that the Group has adequate resources to continue in operation for the foreseeable future.
#  481: Therefore they have adopted the going concern basis in preparing the ﬁnancial statements.
#  482: Charitable donations
#  483: the Company’s selected charity, Macmillan Cancer Relief. The balance was advertising commission donated to the
#  484: Tsunami Relief appeal. The Group made no political donations during the year.
#  485: The auditors, PricewaterhouseCoopers LLP , have indicated their willingness to continue in ofﬁce and a resolution
#  486: that they be re appointed will be proposed at the Annual General Meeting.
#  487: Policy and practice on payment of creditors
#  488: Each Group company is responsible for agreeing the details of terms and conditions relating to transactions with
#  489: its suppliers where goods and services have been supplied in accordance with the relevant terms and conditions of
#  490: Number of shares % of issued share capital
#  491: CORPORATE GOVERNANCE STATEMENT
#  492: As an AIM listed company, UBC Media Group plc is not required to comply with the main provisions of the principles of
#  493: good governance and code of best practice prepared by the Committee on Corporate Governance (the ‘Combined Code’).
#  494: However, the Company supports the principles of good governance laid down in the Combined Code and insofar as they
#  495: are able, for a company of its size, the Board complies with the provisions of the Combined Code.
#  496: This statement provides details of how UBC Media Group has applied these principles and complied insofar as they are
#  497: able for a company of its size with the detailed provisions of Section1 of the Combined Code.
#  498: The Board
#  499: The role of the Chairman and that of the Chief Executive are separate and have been so since the Company’s formation.
#  500: The Senior Non-Executive Director is P .H.B. Pascoe.
#  501: ensuring its effectiveness in all aspects of its role and setting its agenda. The Chairman also ensures that the directors
#  502: receive accurate, timely and clear information and that there is effective communication with shareholders. The
#  503: Chairman also facilitates the effective contribution of the other Non-Executive Directors and ensures constructive
#  504: relations between executive and non-executive directors.
#  505: The Chief Executive’s responsibilities are concerned with co-ordinating the Group’s business and implementing
#  506: Group strategy.
#  507: The Board’s role is to provide entrepreneurial leadership of UBC Media Group within the framework of prudent and
#  508: effective controls that enable risk to be assessed and managed. The Board is responsible for setting the Company’s
#  509: strategic aims and for ensuring the ﬁnancial and human resources are in place for the Company to meet its objectives
#  510: and to review management performance. The Board is also responsible for setting the Company’s values and standards
#  511: and ensuring that its obligations to its shareholders are understood and met.
#  512: The Board dispatches its role by holding bi-monthly meetings, at which:
#  513: –  monthly management accounts, including budgets and prior year comparatives, are presented and reviewed;
#  514: –  strategy is set and policy is debated;
#  515: –  all signiﬁcant investment and acquisition opportunities are reviewed and, if appropriate, approval is given;
#  516: –  any proposed changes to internal control and operating policies are debated.
#  517: The Non-Executive Directors bring a wide range of experience and expertise to the Company’s affairs which allows
#  518: them to constructively challenge and help develop proposals and strategy, scrutinise performance and controls and take
#  519: decisions objectively in the interests of the Company. N.E. Edmonds and P .H.B. Pascoe, as representatives of Unique
#  520: Communications Limited, a signiﬁcant shareholder in the Company, are not considered by the Board to be independent.
#  521: In addition, T.J. Blackmore and I.M. Peacock, by reasons of their signiﬁcant shareholdings in the Company, are not
#  522: considered by the Board to be independent; and K.R. Harris, by reason of his signiﬁcant shareholding in the Company,
#  523: was not considered by the Board to be independent.
#  524: All directors are subject to election by shareholders at the ﬁrst opportunity after appointment and to re-election every
#  525: The Company indemniﬁes directors for claims made against them in relation to their duties, with the exception of any
#  526: respect of potential legal action.
#  527: The Board of Directors meets formally approximately six times a year. During the year attendance at formal meetings
#  528: of the Board was as follows: T.J. Blackmore, S.A. Cole, K.R. Harris, K.F. Harrison, M.A. Honey, P .H.B. Pascoe, J.P .
#  529: Quinn and R.S. Silverstone attended on six occasions; J.H. Donald attended ﬁve meetings; and I.M. Peacock attended
#  530: of the Board. In addition there were a number of informal meetings of the Board.
#  531: The Company has adopted the Model Code for Directors’ dealings as applicable to AIM companies.
#  532: Financial Reporting and Going Concern
#  533: The Board places considerable emphasis on ensuring that all communications with shareholders present a balanced
#  534: and transparent assessment of the Group’s position and prospects. The Board or a sub-committee of the Board reviews
#  535: and approves results announcements, interim reports, annual reports, the Chairman’s AGM statement and trading
#  536: updates prior to their release. The directors’ statement of responsibilities in respect of the preparation of ﬁnancial
#  537: Internal Controls & Risk Management
#  538: The Board is responsible for maintaining a sound system of internal control to safeguard shareholders’ investments and
#  539: the Company’s assets. Such a system is designed to manage rather than eliminate the risk of failure to achieve business
#  540: objectives and can provide only reasonable and not absolute assurance against material misstatement or loss. The
#  541: Board regularly reviews this process and the effectiveness of the Group’s system of internal controls. The review
#  542: covers all material controls, including ﬁnancial, operational and compliance controls and risk management systems.
#  543: Committees of the Board
#  544: The Board has three standing committees, being the Audit Committee, the Remuneration Committee and the
#  545: Nominations Committee, each of which operate within deﬁned terms of reference.
#  546: Audit Committee
#  547: The Audit Committee consists of P .B.H. Pascoe, as chairman, K.F. Harrison and R.S. Silverstone. The Audit Committee
#  548: UBC MEDIA GROUP PLC
#  549: CORPORATE GOVERNANCE STATEMENT CONTINUED
#  550: Company’s internal ﬁnancial controls; ensuring that the ﬁnancial performance of the Company is properly measured and
#  551: reported on; and for reviewing reports from the Company’s auditors relating to the Company’s accounting and internal
#  552: ﬁnancial controls. The Finance Director and other senior management also attend committee meetings by invitation.
#  553: The Committee has direct access to the Company’s auditors and meets with the auditors at least once a year without
#  554: executive management being present. The Audit Committee met formally twice during the year.
#  555: K.F. Harrison and R.S. Silverstone were members of the Committee. Since the year-end I.M. Peacock and K.R. Harris
#  556: resigned as members of the Audit Committee and P .B.H. Pascoe was appointed as chairman of the Audit Committee.
#  557: Remuneration Committee
#  558: The Remuneration Committee consists of K.F. Harrison, as chairman, J. Hodson, P .H.B. Pascoe and R.S. Silverstone.
#  559: The Remuneration Committee met formally four times during the year.
#  560: K.R. Harris, K.F. Harrison and R.S. Silverstone were members of the Committee. Since the year-end I.M. Peacock
#  561: and K.R. Harris resigned as members of the Remuneration Committee, J. Hodson was appointed as a member and
#  562: K.F. Harrison was appointed as chairman of the Remuneration Committee.
#  563: Nominations Committee
#  564: The Nominations Committee is responsible for succession planning and ensuring that all appointments to the Board are
#  565: objective. The Committee oversees the selection and appointment of directors, making its recommendations to the full
#  566: Board. The Committee meets as and when required. The Nominations Committee met twice during the year.
#  567: The Committee consists of J. Hodson, as chairman, S.A. Cole and J.H. Donald.
#  568: member of the Committee. Since the year-end I.M. Peacock and K.R. Harris resigned as members of the Committee
#  569: and J. Hodson was appointed as a member and as chairman of the Nominations Committee.
#  570: Relations with Shareholders
#  571: The Board is committed to maintaining good communications with shareholders. The Chief Executive and the Finance
#  572: Director maintain a regular dialogue with institutional shareholders throughout the year. The executive directors give
#  573: presentations to analysts and hold one-to-one formal meetings with the Group’s key shareholders immediately following
#  574: the announcement of the Group’s full year and interim results. The Group obtains independent feedback on these
#  575: meetings through its corporate brokers, and this feedback is disclosed to the Board.
#  576: The Company responds formally to all queries and requests for information from existing and prospective shareholders.
#  577: In addition, J. Hodson and P .H.B. Pascoe are available to shareholders to ensure that any potential concerns can be
#  578: raised directly. The Group’s Annual Report and Accounts, preliminary and interim announcements, trading statements
#  579: Constructive use of the AGM
#  580: The Board uses the Annual General Meeting to communicate with both institutional and private shareholders.
#  581: Resolutions are proposed on each substantially separate issue and the agenda includes a resolution to adopt the
#  582: Group’s Annual Report and Accounts. Details of the proxy votes for and against each resolution are announced after
#  583: the result of the hand votes is known. After the formal business of the Meeting has been concluded, the Chairman
#  584: STATEMENT OF DIRECTORS’ RESPONSIBILITIES
#  585: Company law requires the directors to prepare ﬁnancial statements for each ﬁnancial year that give a true and fair view of the state of affairs of the
#  586: Company and the Group and of the proﬁt or loss of the Group for that year. The directors are required to prepare the ﬁnancial statements on the going
#  587: concern basis, unless it is inappropriate to presume the Group will continue in business.
#  588: The directors conﬁrm that, in preparing the ﬁnancial statements, suitable accounting policies have been used and applied. They also conﬁrm that
#  589: applicable accounting standards have been followed.
#  590: The maintenance and integrity of the Company’s websites is the responsibility of the directors. Legislation in the United Kingdom governing the
#  591: preparation and dissemination of ﬁnancial statements may differ from legislation in other jurisdictions.
#  592: The directors are responsible for maintaining proper accounting records that disclose with reasonable accuracy at any time the ﬁnancial position of the
#  593: safeguarding the assets of the Company and the Group and hence for taking reasonable steps for the prevention and detection of fraud and
#  594: other irregularities.
#  595: By order of the Board
#  596: Simon Howell
#  597: Company Secretary
#  598: London NW1 5DF
#  599: UBC MEDIA GROUP PLC
#  600: REMUNERATION REPORT
#  601: Directors’ service contracts
#  602: Harrison, P .H.B. Pascoe and R.S. Silverstone may be terminated at any time by the Company on three months’ notice.
#  603: However, we voluntarily disclose the following information.
#  604: The Board has established a Remuneration Committee with formally delegated duties and responsibilities,
#  605: consisting of K.F. Harrison as chairman, J. Hodson, P .H.B. Pascoe and R.S. Silverstone. The provisions of the
#  606: Combined Code (the Code) recommend that as Company Chairman, J. Hodson should not be a member of the
#  607: Committee. However, it is considered that J. Hodson’s experience and knowledge is of considerable value to
#  608: the Committee and as a result he has been appointed a member of the Committee. The Remuneration Committee
#  609: has responsibility for determining executive directors’ terms and conditions of service, including remuneration
#  610: and grant of options under the Share Option Schemes.
#  611: Remuneration policy for executive directors
#  612: The Company’s policy on executive director remuneration is to:
#  613: –  attract and retain high quality executives by paying competitive remuneration packages relevant to each
#  614: director’s role, experience and the external market; and
#  615: Non-executive
#  616: – incentivise directors to maximise shareholder value through share options and the payment of an annual bonus.
#  617: performance at divisional and Group level, the maximum potential annual bonus for all executive directors
#  618: market expectation.
#  619: INDEPENDENT AUDITORS’ REPORT
#  620: Independent auditors’ report to the members of UBC Media Group plc
#  621: We have audited the ﬁnancial statements, which comprise the consolidated proﬁt and loss account, the consolidated and company balance sheets,
#  622: the consolidated cash ﬂow statement, and the related notes.
#  623: Respective responsibilities of directors and auditors
#  624: The directors’ responsibilities for preparing the annual report and the ﬁnancial statements in accordance with applicable United Kingdom law and
#  625: accounting standards are set out in the statement of directors’ responsibilities.
#  626: Our responsibility is to audit the ﬁnancial statements in accordance with relevant legal and regulatory requirements and United Kingdom Auditing
#  627: Standards issued by the Auditing Practices Board. This report, including the opinion, has been prepared for and only for the company’s members as a body
#  628: for any other purpose or to any other person to whom this report is shown or into whose hands it may come save where expressly agreed by our prior
#  629: consent in writing.
#  630: We report to you our opinion as to whether the ﬁnancial statements give a true and fair view and are properly prepared in accordance with the Companies
#  631: accounting records, if we have not received all the information and explanations we require for our audit, or if information speciﬁed by law regarding
#  632: directors’ remuneration and transactions is not disclosed.
#  633: We read the other information contained in the annual report and consider the implications for our report if we become aware of any apparent
#  634: misstatements or material inconsistencies with the ﬁnancial statements. The other information comprises only the Chairman’s Statement, the Chief
#  635: Executive’s Statement, the Financial Review, the Report of the Directors, the Corporate Governance Statement and the Remuneration Report.
#  636: Basis of audit opinion
#  637: We conducted our audit in accordance with auditing standards issued by the Auditing Practices Board. An audit includes examination, on a test basis,
#  638: of evidence relevant to the amounts and disclosures in the ﬁnancial statements. It also includes an assessment of the signiﬁcant estimates and
#  639: judgements made by the directors in the preparation of the ﬁnancial statements, and of whether the accounting policies are appropriate to the company’s
#  640: circumstances, consistently applied and adequately disclosed.
#  641: We planned and performed our audit so as to obtain all the information and explanations which we considered necessary in order to provide us with
#  642: sufﬁcient evidence to give reasonable assurance that the ﬁnancial statements are free from material misstatement, whether caused by fraud or other
#  643: irregularity or error. In forming our opinion we also evaluated the overall adequacy of the presentation of information in the ﬁnancial statements.
#  644: PricewaterhouseCoopers LLP
#  645: Chartered Accountants and Registered Auditors
#  646:
#  647: Before Goodwill Goodwill
#  648: Before Goodwill Goodwill  and Digital and Digital
#  649: and Digital and Digital  Licences Licences
#  650: Licences Licences Total *restated *restated Total
#  651:
#  652:
#  653: Total operating proﬁt/(loss):
#  654: Proﬁt/(loss) on ordinary activities
#  655: Proﬁt/(loss) on ordinary activities
#  656:
#  657: Proﬁt/(loss) per share
#  658: All activities relate to continuing operations. The group has no recognised gains and losses other than those included in
#  659: the proﬁt/(loss) above,and therefore no separate statement of total recognised gains and losses has been presented.
#  660: UBC MEDIA GROUP PLC CONSOLIDATED BALANCE SHEET
#  661: Fixed assets
#  662:
#  663:
#  664: Current assets
#  665:
#  666: Capital and reserves
#  667:
#  668: Current assets
#  669:
#  670: Capital and reserves
#  671: These ﬁnancial statements, which comprise the consolidated proﬁt and loss account, the consolidated and company balance sheets, the consolidated
#  672:
#  673:
#  674: J H Donald S A Cole
#  675: Director Director
# ...
#  773: outstanding. Assets held under ﬁnance leases are depreciated over the shorter of the lease terms and the useful
#  774: lives of equivalent owned assets.
#  775: Costs of share options schemes
#  776: group will be obliged to pay National Insurance contributions on the difference between the market value of the
#  777: underlying shares and their exercise price when the options are exercised. The liability is estimated using the
#  778: market value of the Company’s shares at each balance sheet date. The movement in the provision is charged to the
#  779: proﬁt and loss account as a staff cost.
#  780: The group is also obliged to pay National Insurance contributions on the difference between the market value
#  781: at the date of the grant (or the market value at each balance sheet date, if lower) and the option price for share
#  782: options issued under the Enterprise Management Incentive Scheme.
#  783: Costs incurred on issue of shares
#  784: raising of new equity funds. These include fees from professional advisors.
#  785: Financial instruments
#  786: The group does not use or trade in derivative ﬁnancial instruments.
#  787: Capital instruments that contain an obligation to transfer economic beneﬁt, such as debt issues, are classiﬁed as
#  788: liabilities and are recorded at their net proceeds. The ﬁnance costs in respect of such liabilities recognised in the
#  789: proﬁt and loss account are allocated to periods over the term of the instrument at a constant rate on the carrying
#  790: amount. Financial assets are recorded at cost and the return on such assets is accrued in the period to which it
#  791: relates.
#  792:
#  793: accounted for the combination using merger accounting principles as a result of the group reconstruction. The
#  794: the assets and liabilities of The Unique Broadcasting Company Limited which have been recorded at their book
#  795: values immediately prior to their merger and no adjustments were required to be made to the net assets of UBC
#  796: Media Group plc. The book value of net assets of UBC Media Group plc and The Unique Broadcasting Company
#  797: and the nominal value of The Unique Broadcasting Company Limited’s shares and share premium acquired of
#  798: UBC MEDIA GROUP PLC
#  799: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  800: Geographical analysis by destination
#  801: Joint ventures
#  802:
#  803: The Directors consider that the Group’s business consists of one business segment. All the activities are carried out in
#  804: the United Kingdom from continuing operations.
#  805:
#  806:
#  807:
#  808:
#  809:
#  810: Operating loss is stated after charging/(crediting):
#  811: Depreciation of tangible ﬁxed assets
#  812: Operating lease charges
#  813:
#  814: Goodwill and digital licences comprise the following:
#  815: Continuing operations
#  816: economic life of the eighteen licences.
#  817: Share of operating loss in joint ventures
#  818:
#  819:
#  820: UBC MEDIA GROUP PLC
#  821: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  822:
#  823: Emoluments payable to the highest paid director are as follows:
#  824: No share options were exercised by the highest paid director during the year
#  825:
#  826: – share of joint ventures  –   –
#  827: – share of joint ventures  – –
#  828:
#  829: Effects of:
#  830:
#  831: Basic loss per share is calculated by dividing the loss attributable to shareholders by the weighted average number of ordinary shares in issue during the year.
#  832: For diluted loss per share, the weighted average number of ordinary shares in issue is adjusted to assume conversion of all potential dilutive ordinary shares.
#  833: calculation are set out below.
#  834: Weighted average Per share  Weighted average Per share
#  835: Earnings number of shares amount  Earnings number of shares amount
#  836: Basic EPS
#  837:
#  838:
#  839:
#  840: Purchased Purchased Goodwill arising
#  841: intangible assets goodwill on consolidation Total
#  842: Net book value
#  843:
#  844: UBC MEDIA GROUP PLC
#  845: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  846: refurbishment   building equipment equipment equipment vehicles Total
#  847:
#  848:
#  849: Net book value
#  850:
#  851: Group and Company ﬁxed asset investments
#  852: – Goodwill  – –
#  853: – Goodwill (transferred on consolidation) – –
#  854: Amortisation charge for the year
#  855: – Impairment – –
#  856: UBC MEDIA GROUP PLC
#  857: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  858:
#  859: Taxation –  –
#  860: Due after more than one year
#  861: The loan is interest free and repayable at the discretion of the Board of The Digizone Limited.
#  862: and repayable at the discretion of the Board of The Digizone Limited. This loan has been written down in line with expected future cash ﬂows from digital
#  863: radio in the short term, which is consistent with other digital investments made by the Group.
#  864: Due within one year
#  865:
#  866: Amounts owed by joint ventures are interest free and repayable on demand.
#  867: UBC MEDIA GROUP PLC
#  868: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  869:
#  870:
#  871:
#  872: Investments in joint ventures
#  873: Deferred taxation
#  874: the extent that the transfer of economic beneﬁts in future is more likely than not.
#  875: been recognised in respect of trading losses on the basis that deferred tax assets are only recognised to the extent that the transfer of economic beneﬁts
#  876: in future is more likely than not.
#  877: Group Company
#  878: Authorised:
#  879: Allotted, called up and fully paid:
#  880: Issued share capital
#  881: No employees exercised their share options.
#  882:
#  883: Potential issue of ordinary shares
#  884: shares subject to options, the years in which they were granted and the periods in which they may be exercised are given below:
#  885:
#  886: Year of the grant (year ended) (pence) period number number
#  887: UBC MEDIA GROUP PLC
#  888: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  889: Group and Company Group and Company Group and Company Group Group Company
#  890: Shares to be issued  Share premium account  Merger reserve  Other reserves   Proﬁt & loss   Proﬁt & loss
#  891:
#  892:
#  893: As at  Other non–cash As at
#  894: Book value  Revaluations  Fair Value
#  895: Consideration satisﬁed by:
#  896: UBC MEDIA GROUP PLC
#  897: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  898: Annual commitment under non-cancellable operating leases expiring:
#  899: Land and buildings Other Total  Land and buildings Other Total
#  900: Book value  Revaluations  Fair Value
#  901: Consideration satisﬁed by:
#  902:
#  903:
#  904: The Group’s ﬁnancial instruments comprise borrowings, cash and liquid resources and various items, including
#  905: trade debtors and trade creditors that arise directly from the operations. The main purpose of these ﬁnancial
#  906: instruments is to raise ﬁnance for the Group’s operations.
#  907: Objectives, policies and strategies
#  908: It is, and has been throughout the year under review, the group’s policy not to use or trade in derivative ﬁnancial
#  909: instruments.
#  910: The Group’s ﬁnancial instruments comprise its borrowings, consisting of its loan and convertible loan notes, bank
#  911: overdrafts and ﬁnance lease liabilities, cash and short-term deposits, loans to its joint ventures and various items
#  912: such as trade debtors and trade creditors that arise directly from its operations. The main purpose of the ﬁnancial
#  913: liabilities is to provide ﬁnance for the Group’s operations in the year between raising equity funding. The main
#  914: purpose of the ﬁnancial assets is to provide some ﬁnance to its joint ventures or as a store of liquid resources.
#  915: The Group has no exposure to foreign currency risk; thus the main risks arising from the Group’s ﬁnancial
#  916: instruments are interest rate risk and liquidity risk. The Board reviews and agrees policies for managing these risks
#  917: and they are summarised below. These policies have remained unchanged throughout the year under review.
#  918: Interest rate risk
#  919: The Group primarily ﬁnances its operations through raising of equity ﬁnance from its shareholders and thus is not
#  920: generally exposed to interest rate risk on ﬁnancial liabilities. However, some ﬁnancing of ﬁxed assets has been
#  921: achieved using ﬂoating rate ﬁnance leases and in the past a small amount of temporary funding has been taken
#  922: level, the group has not sought to protect itself from the adverse cash ﬂow effects should market interest rates
#  923: rise.
#  924: In respect of its loans to its joint ventures these are in the nature of quasi-equity and do not bear interest.
#  925: Consequently, the Group bears the loss of a return on these investments
#  926: The Group’s policy is to ensure that to the best of its ability it maximises the interest income on its surplus cash.
#  927: This involves placing cash in a mix of ﬁxed rate and ﬂoating rate short-term deposits. There is no prescribed ratio
#  928: of ﬁxed to ﬂoating rate.
#  929: Liquidity risk
#  930: The Group’s policy throughout the year under review has been to ensure the continuity of funding. Of the
#  931: Short-term debtors and creditors
#  932: Short-term debtors and creditors have been excluded from the disclosures.
#  933:
#  934: Legal Claim
#  935: The directors have sought legal advice in connection with legal claims being brought against The Unique
#  936: Broadcasting Company Limited (“Unique”) by one of their customers for services provided by Unique. In November
#  937: against the Italian courts having jurisdiction to try the case under all counts with the exception of pre-contractual
#  938: liabilities. Having considered legal advice, the directors are conﬁdent of successfully defending this claim, however
#  939: factor associated with legal action. RDS has indicated their willingness to settle and have indicated that the
#  940: have delayed their judgment on the ﬁnal outstanding claim of pre-contracted liability pending the settlement
#  941: of the dispute.
#  942:
#  943: The assets of the money purchase pension schemes are held in separate trustee-administered funds. The Group
#  944:
#  945:
#  946: FRS8 “Related Party Transactions” requires the disclosure of the details of transactions between the reporting
#  947: entity and related parties. The Group has taken advantage of the exemption under FRS8 not to disclose
#  948: transactions between group companies.
#  949: Transactions with directors
#  950: During the year there were no transactions with directors.
#  951: Transactions with joint ventures
#  952: facilities.
#  953: UBC MEDIA GROUP PLC
#  954: Interest risk proﬁle
#  955: Financial assets
#  956: Loans to joint ventures
#  957: All of the above are in sterling.
#  958: relevant LIBID equivalents or government bond rates. The loans to joint ventures are interest free and repayable at the discretion of the Board of
#  959: The Digizone Limited.
#  960: Financial liabilities
#  961: The above are in sterling.
#  962:
#  963: Maturity of ﬁnancial liabilities
#  964: dates. The Company will become unconditionally liable to pay the National Insurance upon exercise of the options. The amount of National Insurance
#  965: payable will depend upon the number of employees who remain with the Company and exercise their options, the market value of the Company’s
#  966: % % Principal activity
#  967: Subsidiaries: immediate holding company
#  968: UBC Media Group plc
#  969: Subsidiaries: immediate holding company
#  970: The Unique Broadcasting Company Limited
#  971: Joint venture of UBC Media Group plc
#  972: Joint ventures of the Unique Broadcasting Company Limited
#  973: All subsidiaries are consolidated into the ﬁnancial information of the Group.
#  974: All joint ventures companies are registered in England and Wales as private companies limited by shares. The joint ventures have been included in the
#  975: UBC MEDIA GROUP PLC
#  976: NOTICE OF ANNUAL GENERAL MEETING
#  977: Notes:
#  978: more proxies to attend and (on a poll) vote instead of him. A proxy need not
#  979: be a member of the Company.
#  980: A proxy card is enclosed.
#  981: of the service agreements between the Company and its Directors will be
#  982: available for inspection at the registered ofﬁce of the Company during usual
#  983: business hours on any weekday (Saturdays and public holidays excluded)
#  984: until the date of the Meeting and also on the date and at the place of
#  985: the Meeting from ﬁfteen minutes prior to its commencement until the
#  986: conclusion of the Meeting.
#  987: to attend or vote at the aforesaid annual general meeting in respect of
#  988: the number of shares registered in their name at that time. Changes to
#  989: disregarded in determining the rights of any person to attend or vote at the
#  990: meeting.
#  991: NOTICE IS HEREBY GIVEN that the ﬁfth Annual General Meeting of the Company will be held at the ofﬁces of Wragge & Co LLP ,
#  992: Ordinary Business:
#  993: accounts are laid before the Company and that their remuneration be ﬁxed by the directors.
#  994: and who, being eligible, offers himself for re-election as a director.
#  995: himself for re-election as a director.
#  996: himself for re-election as a director.
#  997: offers himself for re-election as a director.
#  998: Special Business:
#  999:
#  1000: authority shall expire ﬁfteen months from the date of this resolution or, if earlier, at the conclusion of the Annual General Meeting of the Company in
#  1001: such expiry and the directors may allot relevant securities in pursuance of such offer or agreement as if the authority conferred hereby had not expired.
#  1002:
#  1003: i)  to the allotment of equity securities in connection with a rights issue in favour of shareholders where the equity securities respectively attributable
#  1004: to the interests of all shareholders are proportionate (as nearly as may be) to their holdings of such shares subject to such exclusions or entitlements,
#  1005: statutory restrictions or legal or practical problems under or resulting from the application of the laws of any territory or the requirements of any
#  1006: recognised regulatory body or stock exchange in any territory, and
#  1007: save that the Company may before such expiry make an offer or agreement which would or might require equity securities to be allotted after such
#  1008: expiry and the directors may allot equity securities in pursuance of such offer or agreement as if the power conferred hereby had not expired.
#  1009: By Order of the Board,
#  1010:
#  1011:
#  1012:
#  1013: S.J. Howell, Company Secretary
#  1014: accepted to the exclusion of the votes of the other joint holders. For this purpose seniority is determined by the
#  1015: order in which the names stand in the Register of Members in respect of the joint holding.
#  1016: attorney or ofﬁcer duly authorised.
#  1017: Meeting, or any adjournment thereof, together, if appropriate, with the power of attorney or other authority
#  1018: under which it is signed or a notarially certiﬁed copy of such power or, where the form has been signed by an
#  1019: ofﬁcer on behalf of a corporation, a notarially certiﬁed copy of the authority under which it is signed.
#  1020: abstain as the proxy thinks ﬁt. On any motion to amend any resolution, to propose a new resolution, to adjourn
#  1021: the Meeting, or any other motion put to the Meeting the proxy will act at his/her/their discretion.
#  1022: should be inserted in the relevant place, reference to the Chairman deleted and the alteration initialled.
#  1023: should you subsequently decide to do so.
#  1024: Tear along perforation
#  1025:
#  1026: Please ﬁll in form using BLOCK CAPITALS.
#  1027: I/We (name in full)
#  1028: being (a) holder(s) of ordinary Shares of 1p each of the Company, hereby appoint the duly appointed
#  1029: Chairman* of the Meeting or
#  1030: (insert name and address)
#  1031: adjournment thereof.
#  1032: RESOLUTIONS FOR AGAINST
#  1033: Ordinary business
#  1034: Special business
#  1035:
#  1036:
#  1037:
#  1038: *Before goodwill and digital licences
#  1039: GROUP TURNOVER
#  1040: OPERATING PROFIT/(LOSS)*
#  1041: UBC Media Group PLC
#  1042: London NW1 5DF

# %%
def remove_empty_lists(input_list):

    return [sublist for sublist in input_list if sublist]

clean_sentences = remove_empty_lists(clean_sentences)

for i, clean_sentence in enumerate(clean_sentences):
    print(f" {i+1}: {clean_sentence}")
# Out:
#  1: UBC MEDIA GROUP PLC
#  2: UBC Media Group PLC
#  3: London NW1 5DF
#  4: *Before goodwill and digital licences
#  5: GROUP TURNOVER
#  6: OPERATING PROFIT/(LOSS)*
#  7: RADIO SECTOR. UBC’S RADIO STATIONS INCLUDE THE NATIONAL DIGITAL
#  8: STATIONS, CLASSIC GOLD DIGITAL AND ONEWORD RADIO. UBC IS ALSO A
#  9: LEADING SUPPLIER OF RADIO SERVICES, INCLUDING SOFTWARE TO OPERATE
#  10: DIGITAL RADIO DATA SERVICES. IN ADDITION, UBC RANKS AS THE LEADING
#  11: INDEPENDENT SUPPLIER OF RADIO PROGRAMMES TO THE BBC AND THE
#  12: COMMERCIAL RADIO INDUSTRY.
#  13: GOLD DIGITAL
#  14: GOLD DIGITAL
#  15: UBC MEDIA GROUP PLC
#  16: CHAIRMAN’S STATEMENT
#  17: John Hodson Chairman
#  18: This is the ﬁrst opportunity I have had to write to the shareholders of
#  19: UBC Media Group since my appointment as Chairman of the Company in
#  20: As the new Chairman I think it is helpful to reiterate the strategy that has
#  21: to maximise the returns from UBC’s traditional businesses as a means to ﬁnance
#  22: the Group’s digital expansion, including the signiﬁcant programme of investment
#  23: in its portfolio of digital assets.
#  24: In keeping with UBC’s strategy, I am delighted to report another year of strong
#  25: The growth in the past year reﬂects a combination of both organic growth and
#  26: acquisitions, with positive contributions from all the Group’s main divisions.
#  27: Full details of the performance of each of the Group’s divisions are contained in
#  28: the Financial Review.
#  29: I would like to take this opportunity to extend the thanks of the board to my
#  30: predecessor, Michael Peacock, who performed the role of chairman of UBC with
#  31: business has been enormous, bringing to UBC all the experience gained from a
#  32: long and distinguished career in the media industry. On behalf of my colleagues
#  33: I would like to express my appreciation to Michael for all he has done to guide
#  34: UBC to where it is today and to wish him a long and well deserved retirement.
#  35: Following his decision to stand down as a director, I would also like to thank
#  36: Keith Harris on behalf of the rest of the Board for his long standing contribution
#  37: to the Company, and most recently for his services as a director of UBC.
#  38: The commercial and creative successes of the past year could not have been
#  39: achieved without the enthusiasm and commitment of the whole team at UBC.
#  40: The Company has a highly talented workforce and it is their consistent and
#  41: focused efforts that have enabled us to deliver a further year of strong growth.
#  42: UBC is founded on a culture of innovation and creativity and the strong
#  43: performance of the past year is evidence of the robust and complementary mix of
#  44: businesses within the Group. The Company is led by an established management
#  45: team that is young and energetic, and with ambitions to grow the business
#  46: substantially over the next few years. I believe that with a continuing favourable
#  47: environment the prospects for the Company in the current year are good.
#  48: John Hodson
#  49: Chairman I am pleased to be able to report a further year of strong growth for UBC
#  50: Media Group, delivering on our past commitment to shareholders and
#  51: putting in place a robust foundation for the next stage in the development
#  52: of your company.
#  53: Digital radio is now a success story, with the UK leading the world. Key skills for
#  54: exploiting the digital marketplace are the supply of content, control of spectrum
#  55: and software development. UBC is well placed in each of these areas, with skills
#  56: and experience, as is evident from a number of developments during the last
#  57: year, both in the UK and overseas.
#  58: The high growth digital radio environment that we anticipated and around which
#  59: we have built UBC is now upon us. DAB is proving to be one of the fastest ever
#  60: new technologies to reach mass market status and the industry’s forecasts
#  61: for take-up this year are currently being revised upwards. UBC has sought to
#  62: create the right business mix for an environment that we believe will operate on
#  63: different economic models from that of the traditional analogue radio world.
#  64: The creation of strong brands is of growing importance in what is an increasingly
#  65: Television in our national digital radio station, Oneword Radio, is of particular
#  66: signiﬁcance, and also demonstrates the increasing value of ownership of digital
#  67: radio licences.
#  68: As we predicted, networking and the ability to generate revenues by providing
#  69: programming to stations owned by others is becoming a key part of the digital
#  70: radio economy. It is in this area that we have seen particularly strong growth in
#  71: regional independent production company, Smooth Operations, has made an
#  72: programming. We continue to be one of the leading suppliers of programmes
#  73: to the BBC and the value of this position is ampliﬁed by the BBC’s intention to
#  74: double the programming it commissions from independent production companies.
#  75: Whilst we welcome a step that will beneﬁt our production businesses, it will
#  76: still leave radio outsourcing signiﬁcantly behind that of television. We see no
#  77: CHIEF EXECUTIVE’S STATEMENT
#  78: justiﬁcation for this, and are lobbying government as part of the current Charter
#  79: Review process to encourage greater movement from the BBC.
#  80: Digital radio offers the opportunity to bring real vision to the radio industry. UBC
#  81: Media Group’s strategy has been to anticipate how digital radio will develop,
#  82: and position the Company to beneﬁt from new opportunities as they emerge.
#  83: We believe the ability to transmit data will be one of the key drivers of the
#  84: market share for the provision of software to drive the existing text services that
#  85: accompany digital radio broadcasts. This, however, is only the beginning: devices
#  86: are now being launched which allow full Electronic Programme Guides (EPG) and
#  87: facilitate sophisticated services using digital radio’s data capacity.
#  88: UBC has the only commercially available EPG software in the UK and has already
#  89: licensed this to major UK broadcasters, including GCap Media and the recently
#  90: announced BT Livetime datacasting venture. A major part of our investment in
#  91: UBC and, in particular, on the launch of innovative services that allow music to
#  92: be downloaded over digital radio. We expect to launch such a service in the
#  93: next calendar year.
#  94: UBC’s aim continues to be to grow the business both organically and by
#  95: acquisition. We remain committed to investing in the development of
#  96: our portfolio of digital assets and to maintaining our position at the
#  97: forefront of innovation and technical achievement. Since the start of
#  98: the new ﬁnancial year, as has been widely reported elsewhere, the
#  99: radio advertising market has shown signs of softening. However,
#  100: we continue to see advertising revenues higher than at this
#  101: time last year. The Group continues to perform in line with
#  102: expectations and we believe the prospects for the year
#  103: ahead are positive.
#  104: Simon Cole
#  105: Chief Executive
#  106: UBC IS THE LARGEST INDEPENDENT RADIO PRODUCTION
#  107: OF COMMISSIONED PROGRAMMING FOR THE BBC.
#  108: REGIONAL INDEPENDENT PRODUCTION COMPANY. THE INTEGRATION OF
#  109: SMOOTH OPERATIONS HAS PROGRESSED WELL AND IN THE LAST YEAR THE
#  110: GROUP HAS SEEN STRONG GROWTH IN REVENUES FROM COMMISSIONED
#  111: PROGRAMMING TO THE BBC. UBC IS WELL POSITIONED TO TAKE ADVANTAGE OF
#  112: THE BBC’S PLANS TO INCREASE BOTH ITS REGIONAL OUTPUT AND THE AMOUNT
#  113: OF INDEPENDENTLY PRODUCED PROGRAMMING IT BROADCASTS.  UBC RANKS AS ONE OF THE LARGEST SUPPLIERS OF SYNDICATED
#  114: PROGRAMMES TO COMMERCIAL RADIO – SUPPLYING BOTH THE
#  115: NETWORK DRIVE AND ENTERTAINMENT NEWS SERVICES.
#  116: STRONG GROWTH AS A RESULT OF COMBINING UBC’S AND EMAP’S
#  117: SYNDICATED RADIO AIRTIME SALES NETWORKS AND THE LAUNCH OF A
#  118: CONSOLIDATED TRAFFIC AND TRAVEL SERVICE. THE MARKET FOR UBC’S
#  119: SYNDICATED RADIO PROGRAMMING CONTINUES TO BE STRONG AS THE
#  120: COMMERCIAL RADIO SECTOR INCREASINGLY RECOGNISES ITS NEED TO
#  121: INVEST IN HIGH–QUALITY PROGRAMMING.
#  122: PRIME ASSETS IN DIGITAL RADIO.
#  123: CLASSIC GOLD DIGITAL RANKS AS ONE OF THE TOP ‘GOLD’
#  124: FORMATS IN THE UK, AND IS BROADCAST ON BOTH ANALOGUE
#  125: AND DIGITAL PLATFORMS, REACHING A POTENTIAL UK ADULT
#  126: ONLY COMMERCIAL DIGITAL SPOKEN–WORD LICENCE. WE
#  127: OWNERSHIP OF ONEWORD RADIO IS A KEY DEVELOPMENT IN
#  128: THE GROWTH OF DIGITAL RADIO IN THE UK.
#  129: SERVICES WILL FUNDAMENTALLY CHANGE THE DEVELOPMENT
#  130: OF DIGITAL RADIO.
#  131: UBC EXPECTS THE NEXT FEW YEARS WILL SEE THE LAUNCH OF A NEW
#  132: GENERATION OF RADIO RECEIVERS CAPABLE OF DELIVERING SERVICES
#  133: EPG–ENABLED DEVICES WILL BE FOLLOWED BY THE LAUNCH OF NEW
#  134: RADIO SERVICES, SUCH AS MUSIC DOWNLOADING. UBC’S OWNERSHIP
#  135: OF DATA SPECTRUM AND EXPERIENCE IN RADIO SOFTWARE SERVICES
#  136: PLACES THE GROUP AT THE FOREFRONT OF THIS MARKET.
#  137: UBC MEDIA GROUP PLC
#  138: Financial highlights
#  139: The main ﬁnancial highlights of UBC Media Group for the year to
#  140: –  Operating Proﬁt for the year before goodwill and digital licences
#  141: –  Operating Proﬁt, excluding goodwill and investment in Oneword Radio
#  142: which includes the Company’s investment in Oneword Radio’s digital
#  143: licence while it was a subsidiary company.
#  144: Financial performance by division
#  145: UBC’s Production Division encompasses both the Group’s commissioned
#  146: radio programming for the BBC and syndicated programming for the
#  147: commercial radio industry.
#  148: Commissioned Programming
#  149: UBC’s commissioned programming business for the BBC comprises the
#  150: Group’s historic production business, Unique, and the leading regional
#  151: independent production company, Smooth Operations, which UBC
#  152: The integration of Smooth Operations, which operates from ofﬁces in
#  153: Manchester and Cambridge, has progressed well and Unique continues
#  154: to recover from the expiry of one of its long-standing commissions
#  155: at the start of the ﬁnancial year. Turnover for the year was ahead by
#  156: Unique and Smooth Operations produce a wide range of programmes
#  157: for broadcast across the BBC’s network of national analogue and digital
#  158: programming for the BBC per year across a number of genres, with much
#  159: of their output as long-term commissions for some of the BBC’s ﬂagship
#  160: radio programmes. As an indication of the creative skills within the
#  161: Group, this year UBC received a record number of Sony Radio Academy
#  162: nominations for its programmes, including winning two prestigious Sony
#  163: Radio Academy Gold Awards.
#  164: The acquisition of Smooth Operations, which specialises in the Folk
#  165: and Country music genres, was an important strategic move by UBC in
#  166: a sector that it knows well and where prospects for signiﬁcant organic
#  167: growth have historically been limited. The strategic importance of
#  168: the acquisition of Smooth Operations was underlined by the BBC’s
#  169: in production resources in Manchester. In addition, UBC believes both
#  170: Unique and Smooth Operations are well positioned to beneﬁt from
#  171: the BBC’s announcement during the year that it intends to double
#  172: the number of hours allocated to independent radio production by its
#  173: national radio networks.
#  174: FINANCIAL REVIEW
#  175: Syndicated Programming
#  176: UBC operates two networks of syndicated programmes, Entertainment
#  177: News and the Network Drive trafﬁc & travel service, both of which UBC
#  178: supplies free of charge to radio stations across the UK while retaining
#  179: airtime within each bulletin which is then available to UBC to sell to
#  180: national advertisers.
#  181: airtime sales business followed a doubling of revenues from syndicated
#  182: The signiﬁcant increase in airtime sales revenues in the year reﬂects
#  183: in particular the substantial growth of the trafﬁc & travel news service
#  184: consolidated their competing trafﬁc & travel services into a combined
#  185: by UBC. The network was relaunched in August as one of the largest
#  186: appointment of Trafﬁclink as sole supplier of trafﬁc and travel data to
#  187: the Network Drive service.
#  188: We believe that in the future syndicated programming will become an
#  189: increasingly important feature of the commercial radio market. The
#  190: growth in digital radio will result in there being more radio stations in
#  191: each market, and in response to market fragmentation advertisers will
#  192: seek advertising properties that deliver national reach. One of the main
#  193: challenges facing radio groups in this changed environment will be how
#  194: to provide cost effective, high-quality programming, and in particular
#  195: programming which can compete against the BBC’s output. UBC believes
#  196: that networked programming is likely to form an important part of the
#  197: solution to these competitive challenges.
#  198: As a consequence, UBC is continuing to explore ways in which to grow
#  199: which is also broadcast on MTV. As part of its investment UBC became
#  200: Popworld’s radio partner with exclusive responsibility for exploitation
#  201: of the Popworld brand through networked programming to commercial
#  202: radio stations.
#  203: RADIO STATIONS
#  204: UBC’s two main radio stations are Classic Gold Digital, which broadcasts
#  205: a Classic Hits format on a network of analogue and digital platforms
#  206: across the UK, and the national, digital spoken-word radio station,
#  207: Oneword Radio.
#  208: Classic Gold Digital
#  209: Classic Gold Digital Limited performed in line with expectations in the
#  210: Classic Gold Digital’s revenues are directly based upon the network’s
#  211: audience as measured by RAJAR, in the form of an audience fee that
#  212: GCap Media pays to Classic Gold Digital in return for it selling airtime
#  213: on the network. The RAJAR results during the year for Classic Gold
#  214: Digital have shown a modest decline in audiences. Overall, the long-
#  215: term decline in audiences common to radio services broadcast on AM
#  216: frequencies has been partially compensated for by growth in digital
#  217: audiences. As part of its long-term strategy to maintain audiences,
#  218: Classic Gold Digital has continued to invest throughout the year in high
#  219: quality programming output and marketing.
#  220: The RAJAR report for the ﬁnal quarter of the ﬁnancial year ended
#  221: In addition, the number of listeners in areas where Classic Gold Digital
#  222: growth of digital listening, one of the key challenges facing the radio
#  223: industry in the forthcoming year will be educating advertisers to place
#  224: equal value on both analogue and digital listening.
#  225: to increase its shareholding in Classic Gold Digital from its current
#  226: its shareholding in Classic Gold Digital is based on a formula agreed
#  227: Media of any plans to increase its shareholding in Classic Gold Digital.
#  228: Oneword Radio
#  229: of ensuring the long-term future of the station. As a consequence of
#  230: taking full control of Oneword Radio, the results of UBC for the year to
#  231: UBC MEDIA GROUP PLC
#  232: As a result of a restructuring programme that took place at the same
#  233: time that UBC acquired full control of Oneword Radio, the cost of
#  234: operating Oneword Radio was closely controlled throughout the year.
#  235: At the same time it has shown steady audience growth year-on-year,
#  236: It was UBC’s intention when it acquired full control of Oneword Radio
#  237: to identify a strategic partner for the station with a shared vision of
#  238: the prospects for digital radio in the UK. Following the ﬁnancial year-
#  239: investment in Oneword Radio will reduce in the current year following
#  240: currently working on plans jointly to develop Oneword Radio; building
#  241: on what we believe is a valuable digital asset that has signiﬁcant
#  242: growth prospects.
#  243: RADIO SERVICES
#  244: UBC’s Radio Services division comprises the Group’s digital software
#  245: development and facilities businesses.
#  246: turnover experienced by Radio Services reﬂects a further fall in turnover
#  247: from the Group’s facilities and studios business as we continue to focus
#  248: on higher margin business in this area. This was partly compensated for
#  249: radio industry.
#  250: Unique Interactive
#  251: Unique Interactive continues to beneﬁt from the increasing investment by
#  252: both UK and overseas radio broadcasters in their digital services. Unique
#  253: Interactive’s development focus continues to be on the Group’s two main
#  254: software products: the ‘ManDLS’ software, which is used to manage the
#  255: scrolling text (Dynamic Label Segment) of a digital radio service; and the
#  256: development of software to operate electronic programme guide (EPG)
#  257: services which form part of the interactive capabilities of an emerging
#  258: new generation of EPG-enabled digital devices.
#  259: Unique Interactive’s EPG software continues to be the only commercially
#  260: available radio EPG, and it was a key element in the launch of the ﬁrst
#  261: that the launch of EPG-capable digital radios will signiﬁcantly change
#  262: the way that broadcasters and listeners utilise digital radio, and that
#  263: in the future digital radios will incorporate features as standard which
#  264: will transform the capabilities of the medium, such as rewind, record
#  265: and download. These will enable additional access to a signiﬁcantly
#  266: enhanced range of information services, and will change the current
#  267: common perception that digital radio is only about greater listener
#  268: choice and better sound quality.
#  269: Unique Interactive is a market leader in software development for digital
#  270: radio services as a result of its early investment in this area and it is
#  271: currently developing an increasing international proﬁle in the delivery of
#  272: software solutions to the industry. Unique Interactive is currently working
#  273: with a number of leading broadcasting and technology companies in
#  274: developments that will reinforce UBC’s prominence in this area.
#  275: Since the year-end UBC has announced its intention to invest
#  276: creating an innovative service which will allow music to be downloaded
#  277: over digital radio. The music downloading service will utilise data
#  278: capacity on a number of digital radio multiplexes that are owned by UBC.
#  279: The Company has begun negotiation with partners in the music and radio
#  280: industries with whom it will work on bringing this service to market. The
#  281: Company’s plans in this area are still at an early stage of development,
#  282: but it is intended that investors will be updated on progress at the time
#  283: Unique Facilities
#  284: Unique Facilities delivered a satisfactory performance in the year to
#  285: on the back of good occupancy rates. Despite operating in a highly
#  286: competitive market, UBC’s facilities have operated at full capacity for
#  287: extended periods during the year. In addition, Unique Facilities has
#  288: sought to extend its audio creative services, with the successful launch
#  289: of a number of new products, including the composition of theme and
#  290: incidental music for television programmes and bespoke music jingles.
#  291: Acquisitions & disposals
#  292: million new UBC ordinary shares.
#  293: which broadcasts a regional data service on ﬁve MXR multiplexes, from
#  294: a leading UK independent regional radio producer. The acquisition
#  295: shares satisﬁed the initial acquisition consideration, plus costs incurred
#  296: ordinary shares. The ﬁrst part of the deferred consideration will become
#  297: and new UBC ordinary shares.
#  298: shareholding in Popworld Limited, which owns and controls the
#  299: The option was not exercised.
#  300: of a national television and commercial radio station and potentially
#  301: mirrors the BBC’s ownership of a cross-media brand. UBC and Channel
#  302: brand name.
#  303: Fund Raising and use of proceeds
#  304: expenses) for the Company. The net proceeds of the placing were
#  305: used to satisfy the initial cash consideration and related costs of the
#  306: Limited. The balance of the proceeds will be used to fund the balance of
#  307: any deferred cash consideration of the acquisition.
#  308: Investment in digital radio
#  309: in digital licences:
#  310: Classic Gold Digital on digital multiplexes covering Northern England
#  311: and Greater London and other areas which broaden Classic Gold
#  312: regional data services on ﬁve MXR digital multiplexes.
#  313: Oneword Radio.
#  314: Cash Flow
#  315: During the year UBC had a cash inﬂow from operating activities after
#  316: digital licences and before investment in Oneword Radio and working
#  317: International Financial Reporting Standards (IFRS)
#  318: As a result of a review of its accounting policies it is UBC Media Group’s
#  319: Payment of Dividend
#  320: The Board is not recommending the payment of a dividend.
#  321: Jennifer Donald
#  322: UBC MEDIA GROUP PLC
#  323: BOARD OF DIRECTORS
#  324: John Hodson was appointed to the Board as Non-Executive Chairman of the
#  325: of Singer & Friedlander Group. Other non-executive directorships held by John
#  326: include Domino’s Pizza UK & IRL plc and Prestbury Group. John is Chairman of
#  327: the Nominations Committee and a member of the Remuneration Committee.
#  328: Blackmore, having pioneered the market for national sponsored programmes
#  329: whilst at Piccadilly Radio, where he was Head of Programmes. Simon has
#  330: been awarded a fellowship of the Radio Academy. Simon is a member of
#  331: the Nominations Committee.
#  332: Jennifer Donald qualiﬁed as a chartered accountant with KPMG and has
#  333: held directorships in a number of private and publicly owned companies.
#  334: of McCarthy Corporation plc. Jennifer is a member of the Nominations
#  335: Committee.
#  336: Matthew Honey is Managing Director of Unique Interactive, with
#  337: responsibility for the Group’s Radio Services activities. Matthew joined
#  338: of the Group. Matthew qualiﬁed as a chartered accountant with Coopers
#  339: & Lybrand.
#  340: John Quinn has overall responsibility for the Group’s commercial airtimes sales.
#  341: Editorial Director
#  342: a career in radio production with BBC Radio One and Capital Radio. In April
#  343: from day-to-day executive responsibilities. He continues to act as Group
#  344: Editorial Director for UBC Media Group and as Chairman of Classic Gold
#  345: Digital and Smooth Operations and as a director of Oneword Radio. Tim
#  346: served as the ﬁrst Director of the Radio Academy and was awarded an
#  347: MBE for services to independent radio production. Tim has also been awarded
#  348: a fellowship of the Radio Academy and is Chairman of the Sony Radio
#  349: Academy Awards.
#  350: the Unique Group of companies, a privately owned media and communications
#  351: group engaged in television and event production, video communication and
#  352: talent management.
#  353: Kelvin Harrison is a chartered engineer with signiﬁcant experience of the
#  354: software, electronics and communications sectors in various positions,
#  355: including chief executive of public and private companies. Kelvin is also Chief
#  356: Executive of Maxima Holdings plc. Kelvin is Chairman of the Remuneration
#  357: Committee and a member of the Audit Committee.
#  358: Paul Pascoe is Chief Executive Ofﬁcer of the Unique Group of companies,
#  359: which are engaged in television and event production, video communication
#  360: and talent management. Paul serves as a Non-Executive Director of UBC
#  361: Media Group and is Chairman of the Audit Committee and a member of the
#  362: Remuneration Committee.
#  363: Michael Peacock stood down as Non-Executive Chairman of UBC Media
#  364: Non-Executive Director of UBC Media Group at the Company’s AGM in July
#  365: positions held by him include Managing Director of London Weekend
#  366: Television and Executive Vice President of Warner Bros TV. Michael is also a
#  367: an OBE in the Queen’s Birthday Honours for services to higher education.
#  368: Remuneration committees.
#  369: Roger Silverstone is Professor of Media and Communications at the London
#  370: School of Economics, having previously worked in television research and
#  371: production for London Weekend Television, Associated Television and the
#  372: BBC. Roger is a member of the Audit and Remuneration committees.
#  373: Executive directors
#  374: Simon A Cole
#  375: Jennifer H Donald
#  376: Matthew A Honey
#  377: John P Quinn
#  378: Non-executive directors
#  379: John Hodson
#  380: Timothy J. Blackmore MBE
#  381: Noel E. Edmonds
#  382: Keith R. Harris *
#  383: Kelvin F. Harrison
#  384: Paul H.B. Pascoe
#  385: I. Michael Peacock OBE **
#  386: Roger S. Silverstone
#  387: Company Secretary
#  388: Simon J Howell
#  389: Registered ofﬁce
#  390: London NW1 5DF
#  391: Nominated Adviser
#  392: & Broker
#  393: Seymour Pierce Limited
#  394: Bucklersbury House
#  395: London EC4N 8EL
#  396: Solicitors to the Company
#  397: Wragge & Co LLP
#  398: Birmingham B3 2AS
#  399: PricewaterhouseCoopers Ltd
#  400: London WC2N 6RH
#  401: Principal Bankers
#  402: Coutts & Co
#  403: London WC2R 0QS
#  404: Capita Registrars
#  405: The Registry
#  406: Kent BR3 4TU
#  407: Financial Public Relations
#  408: London WC1V 6QA
#  409: DIRECTORS AND ADVISORS
#  410: ** I.M. Peacock retired as non-executive chairman of UBC Media Group plc on
#  411: REPORT OF THE DIRECTORS
#  412: Principal activities
#  413: The principal business of the Group is the ownership and operation of digital and analogue commercial radio stations, radio programming and the provision of
#  414: audio and data services to the radio industry.
#  415: Directors and their interests
#  416: the name of SocGen Nominees (UK) Limited.
#  417: in the name of his wife Margaret Blackmore.
#  418: name of Unique Communications Limited.
#  419: Honey (GRH Trust).
#  420: that company.
#  421: under the name of Investec Trustees (Jersey Limited) as trustees of the I. M. and D.J.I
#  422: Peacock Voluntary Settlement. I.M. Peacock is due to resign as a director of UBC Media
#  423: have conﬁrmed their intention to hold the options in trust for the above named and their
#  424: families. The Employee Beneﬁt Trust is a discretionary trust for the beneﬁt of the Company’s
#  425: employees, former employees, their families and dependents.
#  426: Share options
#  427: Details of share options and warrants held by directors during the year over the ordinary shares of 1p each in the Company are set out below.
#  428: The options were issued for no consideration.
#  429: Options outstanding Options granted Options relinquished Options exercised Options outstanding Exercise price Date from which
#  430: *  Granted under the Unapproved Executive Share Scheme.
#  431: ** Granted under the Unapproved Executive Share Scheme Number Two.
#  432: *** Granted under the Enterprise Management Incentive Share Option Scheme.
#  433: No. of ordinary shares No. of ordinary shares Ordinary shares under option
#  434: J. Hodson – – –
#  435: UBC MEDIA GROUP PLC
#  436: REPORT OF THE DIRECTORS CONTINUED
#  437: Substantial shareholders
#  438: each in issue at that date:
#  439: Re-election of directors
#  440: In accordance with the Articles of Association J. Hodson, M.A. Honey, J.P . Quinn and R.S. Silverstone offer
#  441: themselves for re-election at the forthcoming AGM, details of which are set out at the back of this annual report.
#  442: Corporate governance
#  443: As an AIM listed company, UBC Media Group plc is not required to comply with the main provisions of the
#  444: principles of good governance and code of best practice prepared by the Committee on Corporate Governance
#  445: (the ‘Combined Code’). However, insofar as they are able for a company of its size, the Board complies with the
#  446: provisions of the Combined Code. Details concerning the Group’s arrangements relating to corporate governance
#  447: Annual General Meeting
#  448: The following special business is being proposed at this year’s Annual General Meeting:
#  449: shareholders. Such a power cannot be given for longer than ﬁve years at any one time and the total nominal value
#  450: of shares that can be allotted must be speciﬁed. In order to renew the Board’s powers in respect of unissued shares
#  451: it is, accordingly, proposed that the directors be granted general authority at any time prior to the expiry of ﬁfteen
#  452: months following the forthcoming Annual General Meeting (or prior to the next Annual General Meeting of the
#  453: of the current issued share capital.
#  454: This resolution is proposed for two reasons. Firstly, it renews the directors’ authority to implement rights issues
#  455: allotment of shares for cash). Secondly, the resolution gives the directors authority to allot shares for cash other
#  456: provide the directors with the ﬂexibility to take advantage of business opportunities as they arise. Shareholders
#  457: should note that the London Stock Exchange does not require shareholders’ speciﬁc approval for each issue
#  458: of passing of the special resolution or, if earlier, on the date of the next Annual General meeting of the Company.
#  459: Employee involvement
#  460: The Group places considerable value on the involvement of its employees and encourages the development of
#  461: employee involvement in each of its operating companies through both formal and informal meetings. It is the
#  462: Group’s policy to ensure that employees are made aware of signiﬁcant matters affecting the performance of the
#  463: Group through information bulletins, informal meetings, team brieﬁngs, internal newsletters and the Group’s
#  464: website and intranet.
#  465: Employee involvement
#  466: The Group acknowledges the vital role that all employees play in its success through their skills, initiative and
#  467: commitment. The Group endorses and supports the principles of equal opportunities and always fully considers
#  468: applications by disabled persons. The policy in respect of staff that become disabled whilst employed is to train
#  469: and assist them wherever practicable to continue within the Group. It is the policy of the Group to consider
#  470: individuals on their merit and to make employment decisions on a non-discriminatory basis in compliance with its
#  471: legal obligations. The Group’s policy is to ensure that, as far as is reasonably practicable, working environments
#  472: exist which will minimise risk to the health and safety of employees.
#  473: Going concern
#  474: reasonable expectation that the Group has adequate resources to continue in operation for the foreseeable future.
#  475: Therefore they have adopted the going concern basis in preparing the ﬁnancial statements.
#  476: Charitable donations
#  477: the Company’s selected charity, Macmillan Cancer Relief. The balance was advertising commission donated to the
#  478: Tsunami Relief appeal. The Group made no political donations during the year.
#  479: The auditors, PricewaterhouseCoopers LLP , have indicated their willingness to continue in ofﬁce and a resolution
#  480: that they be re appointed will be proposed at the Annual General Meeting.
#  481: Policy and practice on payment of creditors
#  482: Each Group company is responsible for agreeing the details of terms and conditions relating to transactions with
#  483: its suppliers where goods and services have been supplied in accordance with the relevant terms and conditions of
#  484: Number of shares % of issued share capital
#  485: CORPORATE GOVERNANCE STATEMENT
#  486: As an AIM listed company, UBC Media Group plc is not required to comply with the main provisions of the principles of
#  487: good governance and code of best practice prepared by the Committee on Corporate Governance (the ‘Combined Code’).
#  488: However, the Company supports the principles of good governance laid down in the Combined Code and insofar as they
#  489: are able, for a company of its size, the Board complies with the provisions of the Combined Code.
#  490: This statement provides details of how UBC Media Group has applied these principles and complied insofar as they are
#  491: able for a company of its size with the detailed provisions of Section1 of the Combined Code.
#  492: The Board
#  493: The role of the Chairman and that of the Chief Executive are separate and have been so since the Company’s formation.
#  494: The Senior Non-Executive Director is P .H.B. Pascoe.
#  495: ensuring its effectiveness in all aspects of its role and setting its agenda. The Chairman also ensures that the directors
#  496: receive accurate, timely and clear information and that there is effective communication with shareholders. The
#  497: Chairman also facilitates the effective contribution of the other Non-Executive Directors and ensures constructive
#  498: relations between executive and non-executive directors.
#  499: The Chief Executive’s responsibilities are concerned with co-ordinating the Group’s business and implementing
#  500: Group strategy.
#  501: The Board’s role is to provide entrepreneurial leadership of UBC Media Group within the framework of prudent and
#  502: effective controls that enable risk to be assessed and managed. The Board is responsible for setting the Company’s
#  503: strategic aims and for ensuring the ﬁnancial and human resources are in place for the Company to meet its objectives
#  504: and to review management performance. The Board is also responsible for setting the Company’s values and standards
#  505: and ensuring that its obligations to its shareholders are understood and met.
#  506: The Board dispatches its role by holding bi-monthly meetings, at which:
#  507: –  monthly management accounts, including budgets and prior year comparatives, are presented and reviewed;
#  508: –  strategy is set and policy is debated;
#  509: –  all signiﬁcant investment and acquisition opportunities are reviewed and, if appropriate, approval is given;
#  510: –  any proposed changes to internal control and operating policies are debated.
#  511: The Non-Executive Directors bring a wide range of experience and expertise to the Company’s affairs which allows
#  512: them to constructively challenge and help develop proposals and strategy, scrutinise performance and controls and take
#  513: decisions objectively in the interests of the Company. N.E. Edmonds and P .H.B. Pascoe, as representatives of Unique
#  514: Communications Limited, a signiﬁcant shareholder in the Company, are not considered by the Board to be independent.
#  515: In addition, T.J. Blackmore and I.M. Peacock, by reasons of their signiﬁcant shareholdings in the Company, are not
#  516: considered by the Board to be independent; and K.R. Harris, by reason of his signiﬁcant shareholding in the Company,
#  517: was not considered by the Board to be independent.
#  518: All directors are subject to election by shareholders at the ﬁrst opportunity after appointment and to re-election every
#  519: The Company indemniﬁes directors for claims made against them in relation to their duties, with the exception of any
#  520: respect of potential legal action.
#  521: The Board of Directors meets formally approximately six times a year. During the year attendance at formal meetings
#  522: of the Board was as follows: T.J. Blackmore, S.A. Cole, K.R. Harris, K.F. Harrison, M.A. Honey, P .H.B. Pascoe, J.P .
#  523: Quinn and R.S. Silverstone attended on six occasions; J.H. Donald attended ﬁve meetings; and I.M. Peacock attended
#  524: of the Board. In addition there were a number of informal meetings of the Board.
#  525: The Company has adopted the Model Code for Directors’ dealings as applicable to AIM companies.
#  526: Financial Reporting and Going Concern
#  527: The Board places considerable emphasis on ensuring that all communications with shareholders present a balanced
#  528: and transparent assessment of the Group’s position and prospects. The Board or a sub-committee of the Board reviews
#  529: and approves results announcements, interim reports, annual reports, the Chairman’s AGM statement and trading
#  530: updates prior to their release. The directors’ statement of responsibilities in respect of the preparation of ﬁnancial
#  531: Internal Controls & Risk Management
#  532: The Board is responsible for maintaining a sound system of internal control to safeguard shareholders’ investments and
#  533: the Company’s assets. Such a system is designed to manage rather than eliminate the risk of failure to achieve business
#  534: objectives and can provide only reasonable and not absolute assurance against material misstatement or loss. The
#  535: Board regularly reviews this process and the effectiveness of the Group’s system of internal controls. The review
#  536: covers all material controls, including ﬁnancial, operational and compliance controls and risk management systems.
#  537: Committees of the Board
#  538: The Board has three standing committees, being the Audit Committee, the Remuneration Committee and the
#  539: Nominations Committee, each of which operate within deﬁned terms of reference.
#  540: Audit Committee
#  541: The Audit Committee consists of P .B.H. Pascoe, as chairman, K.F. Harrison and R.S. Silverstone. The Audit Committee
#  542: UBC MEDIA GROUP PLC
#  543: CORPORATE GOVERNANCE STATEMENT CONTINUED
#  544: Company’s internal ﬁnancial controls; ensuring that the ﬁnancial performance of the Company is properly measured and
#  545: reported on; and for reviewing reports from the Company’s auditors relating to the Company’s accounting and internal
#  546: ﬁnancial controls. The Finance Director and other senior management also attend committee meetings by invitation.
#  547: The Committee has direct access to the Company’s auditors and meets with the auditors at least once a year without
#  548: executive management being present. The Audit Committee met formally twice during the year.
#  549: K.F. Harrison and R.S. Silverstone were members of the Committee. Since the year-end I.M. Peacock and K.R. Harris
#  550: resigned as members of the Audit Committee and P .B.H. Pascoe was appointed as chairman of the Audit Committee.
#  551: Remuneration Committee
#  552: The Remuneration Committee consists of K.F. Harrison, as chairman, J. Hodson, P .H.B. Pascoe and R.S. Silverstone.
#  553: The Remuneration Committee met formally four times during the year.
#  554: K.R. Harris, K.F. Harrison and R.S. Silverstone were members of the Committee. Since the year-end I.M. Peacock
#  555: and K.R. Harris resigned as members of the Remuneration Committee, J. Hodson was appointed as a member and
#  556: K.F. Harrison was appointed as chairman of the Remuneration Committee.
#  557: Nominations Committee
#  558: The Nominations Committee is responsible for succession planning and ensuring that all appointments to the Board are
#  559: objective. The Committee oversees the selection and appointment of directors, making its recommendations to the full
#  560: Board. The Committee meets as and when required. The Nominations Committee met twice during the year.
#  561: The Committee consists of J. Hodson, as chairman, S.A. Cole and J.H. Donald.
#  562: member of the Committee. Since the year-end I.M. Peacock and K.R. Harris resigned as members of the Committee
#  563: and J. Hodson was appointed as a member and as chairman of the Nominations Committee.
#  564: Relations with Shareholders
#  565: The Board is committed to maintaining good communications with shareholders. The Chief Executive and the Finance
#  566: Director maintain a regular dialogue with institutional shareholders throughout the year. The executive directors give
#  567: presentations to analysts and hold one-to-one formal meetings with the Group’s key shareholders immediately following
#  568: the announcement of the Group’s full year and interim results. The Group obtains independent feedback on these
#  569: meetings through its corporate brokers, and this feedback is disclosed to the Board.
#  570: The Company responds formally to all queries and requests for information from existing and prospective shareholders.
#  571: In addition, J. Hodson and P .H.B. Pascoe are available to shareholders to ensure that any potential concerns can be
#  572: raised directly. The Group’s Annual Report and Accounts, preliminary and interim announcements, trading statements
#  573: Constructive use of the AGM
#  574: The Board uses the Annual General Meeting to communicate with both institutional and private shareholders.
#  575: Resolutions are proposed on each substantially separate issue and the agenda includes a resolution to adopt the
#  576: Group’s Annual Report and Accounts. Details of the proxy votes for and against each resolution are announced after
#  577: the result of the hand votes is known. After the formal business of the Meeting has been concluded, the Chairman
#  578: STATEMENT OF DIRECTORS’ RESPONSIBILITIES
#  579: Company law requires the directors to prepare ﬁnancial statements for each ﬁnancial year that give a true and fair view of the state of affairs of the
#  580: Company and the Group and of the proﬁt or loss of the Group for that year. The directors are required to prepare the ﬁnancial statements on the going
#  581: concern basis, unless it is inappropriate to presume the Group will continue in business.
#  582: The directors conﬁrm that, in preparing the ﬁnancial statements, suitable accounting policies have been used and applied. They also conﬁrm that
#  583: applicable accounting standards have been followed.
#  584: The maintenance and integrity of the Company’s websites is the responsibility of the directors. Legislation in the United Kingdom governing the
#  585: preparation and dissemination of ﬁnancial statements may differ from legislation in other jurisdictions.
#  586: The directors are responsible for maintaining proper accounting records that disclose with reasonable accuracy at any time the ﬁnancial position of the
#  587: safeguarding the assets of the Company and the Group and hence for taking reasonable steps for the prevention and detection of fraud and
#  588: other irregularities.
#  589: By order of the Board
#  590: Simon Howell
#  591: Company Secretary
#  592: London NW1 5DF
#  593: UBC MEDIA GROUP PLC
#  594: REMUNERATION REPORT
#  595: Directors’ service contracts
#  596: Harrison, P .H.B. Pascoe and R.S. Silverstone may be terminated at any time by the Company on three months’ notice.
#  597: However, we voluntarily disclose the following information.
#  598: The Board has established a Remuneration Committee with formally delegated duties and responsibilities,
#  599: consisting of K.F. Harrison as chairman, J. Hodson, P .H.B. Pascoe and R.S. Silverstone. The provisions of the
#  600: Combined Code (the Code) recommend that as Company Chairman, J. Hodson should not be a member of the
#  601: Committee. However, it is considered that J. Hodson’s experience and knowledge is of considerable value to
#  602: the Committee and as a result he has been appointed a member of the Committee. The Remuneration Committee
#  603: has responsibility for determining executive directors’ terms and conditions of service, including remuneration
#  604: and grant of options under the Share Option Schemes.
#  605: Remuneration policy for executive directors
#  606: The Company’s policy on executive director remuneration is to:
#  607: –  attract and retain high quality executives by paying competitive remuneration packages relevant to each
#  608: director’s role, experience and the external market; and
#  609: Non-executive
#  610: – incentivise directors to maximise shareholder value through share options and the payment of an annual bonus.
#  611: performance at divisional and Group level, the maximum potential annual bonus for all executive directors
#  612: market expectation.
#  613: INDEPENDENT AUDITORS’ REPORT
#  614: Independent auditors’ report to the members of UBC Media Group plc
#  615: We have audited the ﬁnancial statements, which comprise the consolidated proﬁt and loss account, the consolidated and company balance sheets,
#  616: the consolidated cash ﬂow statement, and the related notes.
#  617: Respective responsibilities of directors and auditors
#  618: The directors’ responsibilities for preparing the annual report and the ﬁnancial statements in accordance with applicable United Kingdom law and
#  619: accounting standards are set out in the statement of directors’ responsibilities.
#  620: Our responsibility is to audit the ﬁnancial statements in accordance with relevant legal and regulatory requirements and United Kingdom Auditing
#  621: Standards issued by the Auditing Practices Board. This report, including the opinion, has been prepared for and only for the company’s members as a body
#  622: for any other purpose or to any other person to whom this report is shown or into whose hands it may come save where expressly agreed by our prior
#  623: consent in writing.
#  624: We report to you our opinion as to whether the ﬁnancial statements give a true and fair view and are properly prepared in accordance with the Companies
#  625: accounting records, if we have not received all the information and explanations we require for our audit, or if information speciﬁed by law regarding
#  626: directors’ remuneration and transactions is not disclosed.
#  627: We read the other information contained in the annual report and consider the implications for our report if we become aware of any apparent
#  628: misstatements or material inconsistencies with the ﬁnancial statements. The other information comprises only the Chairman’s Statement, the Chief
#  629: Executive’s Statement, the Financial Review, the Report of the Directors, the Corporate Governance Statement and the Remuneration Report.
#  630: Basis of audit opinion
#  631: We conducted our audit in accordance with auditing standards issued by the Auditing Practices Board. An audit includes examination, on a test basis,
#  632: of evidence relevant to the amounts and disclosures in the ﬁnancial statements. It also includes an assessment of the signiﬁcant estimates and
#  633: judgements made by the directors in the preparation of the ﬁnancial statements, and of whether the accounting policies are appropriate to the company’s
#  634: circumstances, consistently applied and adequately disclosed.
#  635: We planned and performed our audit so as to obtain all the information and explanations which we considered necessary in order to provide us with
#  636: sufﬁcient evidence to give reasonable assurance that the ﬁnancial statements are free from material misstatement, whether caused by fraud or other
#  637: irregularity or error. In forming our opinion we also evaluated the overall adequacy of the presentation of information in the ﬁnancial statements.
#  638: PricewaterhouseCoopers LLP
#  639: Chartered Accountants and Registered Auditors
#  640: Before Goodwill Goodwill
#  641: Before Goodwill Goodwill  and Digital and Digital
#  642: and Digital and Digital  Licences Licences
#  643: Licences Licences Total *restated *restated Total
#  644: Total operating proﬁt/(loss):
#  645: Proﬁt/(loss) on ordinary activities
#  646: Proﬁt/(loss) on ordinary activities
#  647: Proﬁt/(loss) per share
#  648: All activities relate to continuing operations. The group has no recognised gains and losses other than those included in
#  649: the proﬁt/(loss) above,and therefore no separate statement of total recognised gains and losses has been presented.
#  650: UBC MEDIA GROUP PLC CONSOLIDATED BALANCE SHEET
#  651: Fixed assets
#  652: Current assets
#  653: Capital and reserves
#  654: Current assets
#  655: Capital and reserves
#  656: These ﬁnancial statements, which comprise the consolidated proﬁt and loss account, the consolidated and company balance sheets, the consolidated
#  657: J H Donald S A Cole
#  658: Director Director
#  659: UBC MEDIA GROUP PLC CONSOLIDATED CASH FLOW STATEMENT
#  660: Year ended  Year ended
#  661: Returns on investments and servicing of ﬁnance
# ...
#  742: The capital element of the leasing commitments is shown as obligations under ﬁnance leases. The lease rentals
#  743: are treated as consisting of capital and interest elements. The capital element is applied to reduce the outstanding
#  744: obligations and the interest element is charged against proﬁt in proportion to the reducing capital element
#  745: outstanding. Assets held under ﬁnance leases are depreciated over the shorter of the lease terms and the useful
#  746: lives of equivalent owned assets.
#  747: Costs of share options schemes
#  748: group will be obliged to pay National Insurance contributions on the difference between the market value of the
#  749: underlying shares and their exercise price when the options are exercised. The liability is estimated using the
#  750: market value of the Company’s shares at each balance sheet date. The movement in the provision is charged to the
#  751: proﬁt and loss account as a staff cost.
#  752: The group is also obliged to pay National Insurance contributions on the difference between the market value
#  753: at the date of the grant (or the market value at each balance sheet date, if lower) and the option price for share
#  754: options issued under the Enterprise Management Incentive Scheme.
#  755: Costs incurred on issue of shares
#  756: raising of new equity funds. These include fees from professional advisors.
#  757: Financial instruments
#  758: The group does not use or trade in derivative ﬁnancial instruments.
#  759: Capital instruments that contain an obligation to transfer economic beneﬁt, such as debt issues, are classiﬁed as
#  760: liabilities and are recorded at their net proceeds. The ﬁnance costs in respect of such liabilities recognised in the
#  761: proﬁt and loss account are allocated to periods over the term of the instrument at a constant rate on the carrying
#  762: amount. Financial assets are recorded at cost and the return on such assets is accrued in the period to which it
#  763: relates.
#  764: accounted for the combination using merger accounting principles as a result of the group reconstruction. The
#  765: the assets and liabilities of The Unique Broadcasting Company Limited which have been recorded at their book
#  766: values immediately prior to their merger and no adjustments were required to be made to the net assets of UBC
#  767: Media Group plc. The book value of net assets of UBC Media Group plc and The Unique Broadcasting Company
#  768: and the nominal value of The Unique Broadcasting Company Limited’s shares and share premium acquired of
#  769: UBC MEDIA GROUP PLC
#  770: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  771: Geographical analysis by destination
#  772: Joint ventures
#  773: The Directors consider that the Group’s business consists of one business segment. All the activities are carried out in
#  774: the United Kingdom from continuing operations.
#  775: Operating loss is stated after charging/(crediting):
#  776: Depreciation of tangible ﬁxed assets
#  777: Operating lease charges
#  778: Goodwill and digital licences comprise the following:
#  779: Continuing operations
#  780: economic life of the eighteen licences.
#  781: Share of operating loss in joint ventures
#  782: UBC MEDIA GROUP PLC
#  783: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  784: Emoluments payable to the highest paid director are as follows:
#  785: No share options were exercised by the highest paid director during the year
#  786: – share of joint ventures  –   –
#  787: – share of joint ventures  – –
#  788: Effects of:
#  789: Basic loss per share is calculated by dividing the loss attributable to shareholders by the weighted average number of ordinary shares in issue during the year.
#  790: For diluted loss per share, the weighted average number of ordinary shares in issue is adjusted to assume conversion of all potential dilutive ordinary shares.
#  791: calculation are set out below.
#  792: Weighted average Per share  Weighted average Per share
#  793: Earnings number of shares amount  Earnings number of shares amount
#  794: Basic EPS
#  795: Purchased Purchased Goodwill arising
#  796: intangible assets goodwill on consolidation Total
#  797: Net book value
#  798: UBC MEDIA GROUP PLC
#  799: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  800: refurbishment   building equipment equipment equipment vehicles Total
#  801: Net book value
#  802: Group and Company ﬁxed asset investments
#  803: – Goodwill  – –
#  804: – Goodwill (transferred on consolidation) – –
#  805: Amortisation charge for the year
#  806: – Impairment – –
#  807: UBC MEDIA GROUP PLC
#  808: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  809: Taxation –  –
#  810: Due after more than one year
#  811: The loan is interest free and repayable at the discretion of the Board of The Digizone Limited.
#  812: and repayable at the discretion of the Board of The Digizone Limited. This loan has been written down in line with expected future cash ﬂows from digital
#  813: radio in the short term, which is consistent with other digital investments made by the Group.
#  814: Due within one year
#  815: Amounts owed by joint ventures are interest free and repayable on demand.
#  816: UBC MEDIA GROUP PLC
#  817: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  818: Investments in joint ventures
#  819: Deferred taxation
#  820: the extent that the transfer of economic beneﬁts in future is more likely than not.
#  821: been recognised in respect of trading losses on the basis that deferred tax assets are only recognised to the extent that the transfer of economic beneﬁts
#  822: in future is more likely than not.
#  823: Group Company
#  824: Authorised:
#  825: Allotted, called up and fully paid:
#  826: Issued share capital
#  827: No employees exercised their share options.
#  828: Potential issue of ordinary shares
#  829: shares subject to options, the years in which they were granted and the periods in which they may be exercised are given below:
#  830: Year of the grant (year ended) (pence) period number number
#  831: UBC MEDIA GROUP PLC
#  832: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  833: Group and Company Group and Company Group and Company Group Group Company
#  834: Shares to be issued  Share premium account  Merger reserve  Other reserves   Proﬁt & loss   Proﬁt & loss
#  835: As at  Other non–cash As at
#  836: Book value  Revaluations  Fair Value
#  837: Consideration satisﬁed by:
#  838: UBC MEDIA GROUP PLC
#  839: NOTES TO THE FINANCIAL STATEMENTS CONTINUED
#  840: Annual commitment under non-cancellable operating leases expiring:
#  841: Land and buildings Other Total  Land and buildings Other Total
#  842: Book value  Revaluations  Fair Value
#  843: Consideration satisﬁed by:
#  844: The Group’s ﬁnancial instruments comprise borrowings, cash and liquid resources and various items, including
#  845: trade debtors and trade creditors that arise directly from the operations. The main purpose of these ﬁnancial
#  846: instruments is to raise ﬁnance for the Group’s operations.
#  847: Objectives, policies and strategies
#  848: It is, and has been throughout the year under review, the group’s policy not to use or trade in derivative ﬁnancial
#  849: instruments.
#  850: The Group’s ﬁnancial instruments comprise its borrowings, consisting of its loan and convertible loan notes, bank
#  851: overdrafts and ﬁnance lease liabilities, cash and short-term deposits, loans to its joint ventures and various items
#  852: such as trade debtors and trade creditors that arise directly from its operations. The main purpose of the ﬁnancial
#  853: liabilities is to provide ﬁnance for the Group’s operations in the year between raising equity funding. The main
#  854: purpose of the ﬁnancial assets is to provide some ﬁnance to its joint ventures or as a store of liquid resources.
#  855: The Group has no exposure to foreign currency risk; thus the main risks arising from the Group’s ﬁnancial
#  856: instruments are interest rate risk and liquidity risk. The Board reviews and agrees policies for managing these risks
#  857: and they are summarised below. These policies have remained unchanged throughout the year under review.
#  858: Interest rate risk
#  859: The Group primarily ﬁnances its operations through raising of equity ﬁnance from its shareholders and thus is not
#  860: generally exposed to interest rate risk on ﬁnancial liabilities. However, some ﬁnancing of ﬁxed assets has been
#  861: achieved using ﬂoating rate ﬁnance leases and in the past a small amount of temporary funding has been taken
#  862: level, the group has not sought to protect itself from the adverse cash ﬂow effects should market interest rates
#  863: rise.
#  864: In respect of its loans to its joint ventures these are in the nature of quasi-equity and do not bear interest.
#  865: Consequently, the Group bears the loss of a return on these investments
#  866: The Group’s policy is to ensure that to the best of its ability it maximises the interest income on its surplus cash.
#  867: This involves placing cash in a mix of ﬁxed rate and ﬂoating rate short-term deposits. There is no prescribed ratio
#  868: of ﬁxed to ﬂoating rate.
#  869: Liquidity risk
#  870: The Group’s policy throughout the year under review has been to ensure the continuity of funding. Of the
#  871: Short-term debtors and creditors
#  872: Short-term debtors and creditors have been excluded from the disclosures.
#  873: Legal Claim
#  874: The directors have sought legal advice in connection with legal claims being brought against The Unique
#  875: Broadcasting Company Limited (“Unique”) by one of their customers for services provided by Unique. In November
#  876: against the Italian courts having jurisdiction to try the case under all counts with the exception of pre-contractual
#  877: liabilities. Having considered legal advice, the directors are conﬁdent of successfully defending this claim, however
#  878: factor associated with legal action. RDS has indicated their willingness to settle and have indicated that the
#  879: have delayed their judgment on the ﬁnal outstanding claim of pre-contracted liability pending the settlement
#  880: of the dispute.
#  881: The assets of the money purchase pension schemes are held in separate trustee-administered funds. The Group
#  882: FRS8 “Related Party Transactions” requires the disclosure of the details of transactions between the reporting
#  883: entity and related parties. The Group has taken advantage of the exemption under FRS8 not to disclose
#  884: transactions between group companies.
#  885: Transactions with directors
#  886: During the year there were no transactions with directors.
#  887: Transactions with joint ventures
#  888: facilities.
#  889: UBC MEDIA GROUP PLC
#  890: Interest risk proﬁle
#  891: Financial assets
#  892: Loans to joint ventures
#  893: All of the above are in sterling.
#  894: relevant LIBID equivalents or government bond rates. The loans to joint ventures are interest free and repayable at the discretion of the Board of
#  895: The Digizone Limited.
#  896: Financial liabilities
#  897: The above are in sterling.
#  898: Maturity of ﬁnancial liabilities
#  899: dates. The Company will become unconditionally liable to pay the National Insurance upon exercise of the options. The amount of National Insurance
#  900: payable will depend upon the number of employees who remain with the Company and exercise their options, the market value of the Company’s
#  901: % % Principal activity
#  902: Subsidiaries: immediate holding company
#  903: UBC Media Group plc
#  904: Subsidiaries: immediate holding company
#  905: The Unique Broadcasting Company Limited
#  906: Joint venture of UBC Media Group plc
#  907: Joint ventures of the Unique Broadcasting Company Limited
#  908: All subsidiaries are consolidated into the ﬁnancial information of the Group.
#  909: All joint ventures companies are registered in England and Wales as private companies limited by shares. The joint ventures have been included in the
#  910: UBC MEDIA GROUP PLC
#  911: NOTICE OF ANNUAL GENERAL MEETING
#  912: Notes:
#  913: more proxies to attend and (on a poll) vote instead of him. A proxy need not
#  914: be a member of the Company.
#  915: A proxy card is enclosed.
#  916: of the service agreements between the Company and its Directors will be
#  917: available for inspection at the registered ofﬁce of the Company during usual
#  918: business hours on any weekday (Saturdays and public holidays excluded)
#  919: until the date of the Meeting and also on the date and at the place of
#  920: the Meeting from ﬁfteen minutes prior to its commencement until the
#  921: conclusion of the Meeting.
#  922: to attend or vote at the aforesaid annual general meeting in respect of
#  923: the number of shares registered in their name at that time. Changes to
#  924: disregarded in determining the rights of any person to attend or vote at the
#  925: meeting.
#  926: NOTICE IS HEREBY GIVEN that the ﬁfth Annual General Meeting of the Company will be held at the ofﬁces of Wragge & Co LLP ,
#  927: Ordinary Business:
#  928: accounts are laid before the Company and that their remuneration be ﬁxed by the directors.
#  929: and who, being eligible, offers himself for re-election as a director.
#  930: himself for re-election as a director.
#  931: himself for re-election as a director.
#  932: offers himself for re-election as a director.
#  933: Special Business:
#  934: authority shall expire ﬁfteen months from the date of this resolution or, if earlier, at the conclusion of the Annual General Meeting of the Company in
#  935: such expiry and the directors may allot relevant securities in pursuance of such offer or agreement as if the authority conferred hereby had not expired.
#  936: i)  to the allotment of equity securities in connection with a rights issue in favour of shareholders where the equity securities respectively attributable
#  937: to the interests of all shareholders are proportionate (as nearly as may be) to their holdings of such shares subject to such exclusions or entitlements,
#  938: statutory restrictions or legal or practical problems under or resulting from the application of the laws of any territory or the requirements of any
#  939: recognised regulatory body or stock exchange in any territory, and
#  940: save that the Company may before such expiry make an offer or agreement which would or might require equity securities to be allotted after such
#  941: expiry and the directors may allot equity securities in pursuance of such offer or agreement as if the power conferred hereby had not expired.
#  942: By Order of the Board,
#  943: S.J. Howell, Company Secretary
#  944: accepted to the exclusion of the votes of the other joint holders. For this purpose seniority is determined by the
#  945: order in which the names stand in the Register of Members in respect of the joint holding.
#  946: attorney or ofﬁcer duly authorised.
#  947: Meeting, or any adjournment thereof, together, if appropriate, with the power of attorney or other authority
#  948: under which it is signed or a notarially certiﬁed copy of such power or, where the form has been signed by an
#  949: ofﬁcer on behalf of a corporation, a notarially certiﬁed copy of the authority under which it is signed.
#  950: abstain as the proxy thinks ﬁt. On any motion to amend any resolution, to propose a new resolution, to adjourn
#  951: the Meeting, or any other motion put to the Meeting the proxy will act at his/her/their discretion.
#  952: should be inserted in the relevant place, reference to the Chairman deleted and the alteration initialled.
#  953: should you subsequently decide to do so.
#  954: Tear along perforation
#  955: Please ﬁll in form using BLOCK CAPITALS.
#  956: I/We (name in full)
#  957: being (a) holder(s) of ordinary Shares of 1p each of the Company, hereby appoint the duly appointed
#  958: Chairman* of the Meeting or
#  959: (insert name and address)
#  960: adjournment thereof.
#  961: RESOLUTIONS FOR AGAINST
#  962: Ordinary business
#  963: Special business
#  964: *Before goodwill and digital licences
#  965: GROUP TURNOVER
#  966: OPERATING PROFIT/(LOSS)*
#  967: UBC Media Group PLC
#  968: London NW1 5DF

# %% [markdown]
# # **Preprocessing Completed**

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.3.1

# %% [markdown]
# # **Sentence Embedding**

# %%
from sentence_transformers import SentenceTransformer

def sentence_embedding(sentences, model_name='paraphrase-MiniLM-L6-v2'):

    # Load pre-trained Sentence-BERT model
    model = SentenceTransformer(model_name)

    # Encode sentences to get embeddings
    embeddings = model.encode(sentences)

    return embeddings


embeddings_result = sentence_embedding(clean_sentences)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # **Creating Similarity Graph**

# %%
# Step 3: Create a graph using cosine similarity
def create_similarity_graph(embeddings):
    G = nx.Graph()
    num_sentences = len(embeddings)

    # Convert numpy arrays to PyTorch tensors
    embeddings = [torch.from_numpy(embedding) for embedding in embeddings]

    for i in range(num_sentences):
        for j in range(i + 1, num_sentences):
            # Convert embeddings to PyTorch tensors
            emb_i, emb_j = embeddings[i], embeddings[j]

            # Calculate cosine similarity between embeddings
            similarity_score = cosine_similarity(emb_i.reshape(1, -1), emb_j.reshape(1, -1))[0, 0]

            # Add an edge to the graph with similarity score as weight
            G.add_edge(i, j, weight=(1-similarity_score))

    return G

graph = create_similarity_graph(embeddings_result)

# %% [markdown]
# # **Ranking Sentences**

# %%
# Step 4: Rank sentences by degree centrality
def rank_sentences(graph):
    sum_of_weights = {}

    for node in graph.nodes():
        sum_weight = sum(data['weight'] for _, _, data in graph.edges(node, data=True))
        sum_of_weights[node] = sum_weight

    return sum_of_weights

# Calculate the sum of weights for each node
ranked_sentences = rank_sentences(graph)

sorted_ranked_sentences = dict(sorted(ranked_sentences.items(), key=lambda x: x[1]))

# %% [markdown]
# # **Summary Generation**

# %%
def generate_summary(sentences, ranked_sentences, x):
    top_indices = list(ranked_sentences.keys())[:x]

    # Select sentences from the list based on the top indices
    selected_sentences = [{"index": index, "sentence": sentences[index]} for index in top_indices]
    sorted_sentences = sorted(selected_sentences, key=lambda x: x["index"])
    summary = [item["sentence"] for item in sorted_sentences]
    return summary

# %%
summary = generate_summary(clean_sentences, sorted_ranked_sentences, 65)
sentence_string = ' '.join(summary)
print(sentence_string)
# Out:
# the Group’s digital expansion, including the signiﬁcant programme of investment the Financial Review. businesses within the Group. The Company is led by an established management The main ﬁnancial highlights of UBC Media Group for the year to –  Operating Proﬁt for the year before goodwill and digital licences UBC’s Production Division encompasses both the Group’s commissioned independent production company, Smooth Operations, which UBC from the Group’s facilities and studios business as we continue to focus expenses) for the Company. The net proceeds of the placing were As a result of a review of its accounting policies it is UBC Media Group’s the Unique Group of companies, a privately owned media and communications Remuneration committees. Financial Public Relations DIRECTORS AND ADVISORS REPORT OF THE DIRECTORS The principal business of the Group is the ownership and operation of digital and analogue commercial radio stations, radio programming and the provision of Directors and their interests REPORT OF THE DIRECTORS CONTINUED Substantial shareholders Corporate governance provisions of the Combined Code. Details concerning the Group’s arrangements relating to corporate governance of shares that can be allotted must be speciﬁed. In order to renew the Board’s powers in respect of unissued shares allotment of shares for cash). Secondly, the resolution gives the directors authority to allot shares for cash other provide the directors with the ﬂexibility to take advantage of business opportunities as they arise. Shareholders Group’s policy to ensure that employees are made aware of signiﬁcant matters affecting the performance of the CORPORATE GOVERNANCE STATEMENT This statement provides details of how UBC Media Group has applied these principles and complied insofar as they are ensuring its effectiveness in all aspects of its role and setting its agenda. The Chairman also ensures that the directors The Chief Executive’s responsibilities are concerned with co-ordinating the Group’s business and implementing effective controls that enable risk to be assessed and managed. The Board is responsible for setting the Company’s strategic aims and for ensuring the ﬁnancial and human resources are in place for the Company to meet its objectives and to review management performance. The Board is also responsible for setting the Company’s values and standards and ensuring that its obligations to its shareholders are understood and met. decisions objectively in the interests of the Company. N.E. Edmonds and P .H.B. Pascoe, as representatives of Unique considered by the Board to be independent; and K.R. Harris, by reason of his signiﬁcant shareholding in the Company, and transparent assessment of the Group’s position and prospects. The Board or a sub-committee of the Board reviews updates prior to their release. The directors’ statement of responsibilities in respect of the preparation of ﬁnancial Company’s internal ﬁnancial controls; ensuring that the ﬁnancial performance of the Company is properly measured and Relations with Shareholders The Board is committed to maintaining good communications with shareholders. The Chief Executive and the Finance STATEMENT OF DIRECTORS’ RESPONSIBILITIES Company law requires the directors to prepare ﬁnancial statements for each ﬁnancial year that give a true and fair view of the state of affairs of the Company and the Group and of the proﬁt or loss of the Group for that year. The directors are required to prepare the ﬁnancial statements on the going The directors conﬁrm that, in preparing the ﬁnancial statements, suitable accounting policies have been used and applied. They also conﬁrm that Directors’ service contracts has responsibility for determining executive directors’ terms and conditions of service, including remuneration The Company’s policy on executive director remuneration is to: director’s role, experience and the external market; and – incentivise directors to maximise shareholder value throug ...
